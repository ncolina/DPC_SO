# %%
import pandas as pd
import time
import string
from functions.capitalization import titlecase
so_file='BIGBANG1.txt'
widths = [4,2,15,10,30,100,4,30,3,7,1,30,30,2,20,2,2,10,9,50,3,30,50]
update=pd.read_fwf(so_file,
                   header=None, 
                   widths=widths,
                   names=['dir_code','so_type','sonumber','mem_wstd','first_name','last_name','sam_city'
                          ,'sam_stname','sam_stsubt','sam_stnmfr','sam_subd','sam_estate','sam_bldname','sam_aptcod','sam_aprmnt'
                          ,'list_code','acc_type','old_wstd','so_date','joint_user','regulatory_id','account_no','distribution_code'],
                   converters = {'mem_wstd': str, 'sam_stnmfr':str,'account_no':str,'old_wstd':str,'so_date':str},
                   index_col=None
                  )
#update.()
update = update.fillna('')
update['acc_type']=update['acc_type'].astype('category')


#update.sort_values(by='last_name',inplace=True)
#update.reset_index(drop=True,inplace=True)
#update['acc_type']=update['acc_type'].astype('category')
#update['class_code']=''
#update['src']=so_file.split('/')[-1]
#update['so_rangedate']=time.strftime("%Y/%m/%d")
rr=update

# %%
#rr.loc[rr.dir_code == 'MM','so_type']=400
rr_crm
# Out:
#        Areacode    Phone                                            name1  \
# 0             2  7063050
# 1             2  3983090                "K" Line Logistics (Phils.), Inc.
# 2             2  8251854                "K" Line Logistics (Phils.), Inc.
# 3             2  5562917           "K" Line Maritime Training Corporation
# 4             2  6318181                       (Bank of the Phil Islands)
# 5             2  8967916          (Department of Trade and Industrybsmbd)
# 6             2  8975554            (Department of Trade and Industrycic)
# 7             2  8908907            (Department of Trade and Industryipr)
# 8             2  8904951            (Department of Trade and Industryoop)
# 9             2  8971719          (Department of Trade and Industryticci)
# 10            2  8904857                   (Dept of Trade & Industryhrds)
# 11            2  8905123  (Dept of Trade & Industryofcof Special Concern)
# 12            2  8959460                    (Dept of Trade & Industryopr)
# 13            2  8967889                    (Dept of Trade & Industryopr)
# 14            2  8971243                    (Dept of Trade & Industryopr)
# 15            2  8953995                    (Dept of Trade & Industrypro)
# 16            2  8958133                    (Dept of Trade & Industrypro)
# 17            2  8904517                    (Dept of Trade & Industrypro)
# 18            2  8953558                    (Dept of Trade & Industrypro)
# 19            2  8904747                 (Dept of Trade and Industryftsc)
# 20            2  8901302                 (Dept of Trade and Industryncac)
# 21            2  2563748                 (Lbc) Emt Forwarding Servicesinc
# 22            2  3747268               (Rp) Dept of Budget and Department
# 23            2  7361230               (Rp) Dept of Budget and Department
# 24            2  7361234               (Rp) Dept of Budget and Department
# 25            2  7361284               (Rp) Dept of Budget and Department
# 26            2  7361285               (Rp) Dept of Budget and Department
# 27            2  3747270               (Rp) Dept of Budget and Department
# 28            2  3747269               (Rp) Dept of Budget and Department
# 29            2  9261065       (Rp) Housing and Land Use Regulatory Board
# ...         ...      ...                                              ...
# 57770         2  9972967                            Zed Philippines, Inc.
# 57771         2  9972965                            Zed Philippines, Inc.
# 57772         2  3610820           Zenith International Philippines, Inc.
# 57773         2  8511803                               Zest Airways, Inc.
# 57774         2  5218942                                eCOPY CORPORATION
# 57775         2  8447568                                eCOPY CORPORATION
# 57776         2  5219132                                eCOPY CORPORATION
# 57777         2  5361557                                eCOPY CORPORATION
# 57778         2  5218937                                eCOPY CORPORATION
# 57779         2  8449394                                eCOPY CORPORATION
# 57780         2  5551456                                       ePDS, Inc.
# 57781         2  8086187                                       ePDS, Inc.
# 57782         2  8901164                                       ePDS, Inc.
# 57783         2  8901165                                       ePDS, Inc.
# 57784         2  8934723                                            ePLDT
# 57785         2  5842303                                      ePLDT, Inc.
# 57786         2  4039887                                      ePLDT, Inc.
# 57787         2  4511647                                      ePLDT, Inc.
# 57788         2  2349409                                      ePLDT, Inc.
# 57789         2  2349597                                      ePLDT, Inc.
# 57790         2  5840630                                      ePLDT, Inc.
# 57791         2  2349041                                      ePLDT, Inc.
# 57792         2  6725101                                      ePLDT, Inc.
# 57793         2  2349185                                      ePLDT, Inc.
# 57794         2  8446178                             iPEOPLE INCORPORATED
# 57795         2  8935958                            kgb Philippines, Inc.
# 57796         2  8935960                            kgb Philippines, Inc.
# 57797         2  8935956                            kgb Philippines, Inc.
# 57798         2  8931693                            kgb Philippines, Inc.
# 57799         2  8935937                            kgb Philippines, Inc.
#
#       name2                     SAM_BLDNAME SAM_STNMFR      SAM_STNAME  \
# 0                             Sm Megamall A                       Edsa
# 1                   Oyster Complex Building               Ninoy Aquino
# 2                                                         Ninoy Aquino
# 3                           K-Line Building                   Coralway
# 4                  Mayflower Plaza Building                     United
# 5                              Dti Building        361   Sen Gil Puyat
# 6                              Dti Building        361   Sen Gil Puyat
# 7                              Dti Building        361   Sen Gil Puyat
# 8            Industry & Investment Building        385   Sen Gil Puyat
# 9                               Lc Building        375   Sen Gil Puyat
# 10                             Dti Building              Sen Gil Puyat
# 11             Board of Investment Building        385   Sen Gil Puyat
# 12                             Dti Building        361   Sen Gil Puyat
# 13           Industry & Investment Building        385   Sen Gil Puyat
# 14           Industry & Investment Building        385   Sen Gil Puyat
# 15           Industry & Investment Building        385   Sen Gil Puyat
# 16           Industry & Investment Building        385   Sen Gil Puyat
# 17           Industry & Investment Building        385   Sen Gil Puyat
# 18           Industry & Investment Building        385   Sen Gil Puyat
# 19                       New Solid Building        357   Sen Gil Puyat
# 20                             Dti Building              Sen Gil Puyat
# 21                    TUTUBAN CENTER MALL 1                  C M Recto
# 22                   Ben-Lor Annex Building       1184          Quezon
# 23                           DBM BUILDING 1        755      Gen Solano
# 24                           DBM BUILDING 1        755      Gen Solano
# 25                           DBM BUILDING 1        755      Gen Solano
# 26                           DBM BUILDING 1        755      Gen Solano
# 27                   Ben-Lor Annex Building       1184          Quezon
# 28                   Ben-Lor Annex Building       1184          Quezon
# 29                       Sunnymede Building       1614          Quezon
# ...     ...                             ...        ...             ...
# 57770                   Marco Polo Building                   Sapphire
# 57771                   Marco Polo Building                   Sapphire
# 57772                                               78             5TH
# 57773                      Domestic Airport                   Domestic
# 57774                       Cygnet Building       5837     Zobel Roxas
# 57775                                               65   Sen Gil Puyat
# 57776                       Cygnet Building       5837     Zobel Roxas
# 57777                                             5837     Zobel Roxas
# 57778                       Cygnet Building       5837     Zobel Roxas
# 57779                                               65   Sen Gil Puyat
# 57780                                             2112    Primo Rivera
# 57781                                             2112    Primo Rivera
# 57782                                             2112    Primo Rivera
# 57783                                             2112    Primo Rivera
# 57784                   L v Locsin Building       6752           Ayala
# 57785                          Idc Building                     Canley
# 57786                          Spi Building             Nicanor Garcia
# 57787                          Idc Building                    D Floro
# 57788                          Idc Building                    D Floro
# 57789                          Idc Building                    D Floro
# 57790                          Idc Building                     Canley
# 57791                          Idc Building                    D Floro
# 57792                          Idc Building                    D Floro
# 57793                          Idc Building                    D Floro
# 57794              Grepalife Annex Building        221   Sen Gil Puyat
# 57795          RCBC PLAZA YUCHENGCO TOWER 2       6819           Ayala
# 57796          RCBC PLAZA YUCHENGCO TOWER 2       6819           Ayala
# 57797          RCBC PLAZA YUCHENGCO TOWER 2       6819           Ayala
# 57798          RCBC PLAZA YUCHENGCO TOWER 2       6819           Ayala
# 57799          RCBC PLAZA YUCHENGCO TOWER 2       6819           Ayala
#
#       SAM_STSUBT               sam_estate              City      Province  \
# 0            Ave                           Mandaluyong City  METRO MANILA
# 1            Ave                             Paranaque City  METRO MANILA
# 2            Ave                             Paranaque City  METRO MANILA
# 3            Drv  CENTRAL BUSINESS PARK 1        Pasay City  METRO MANILA
# 4             St                           Mandaluyong City  METRO MANILA
# 5            Ave                                Makati City  METRO MANILA
# 6            Ave          Bel-Air Village       Makati City  METRO MANILA
# 7            Ave          Bel-Air Village       Makati City  METRO MANILA
# 8            Ave          Bel-Air Village       Makati City  METRO MANILA
# 9            Ave          Bel-Air Village       Makati City  METRO MANILA
# 10           Ave          Bel-Air Village       Makati City  METRO MANILA
# 11           Ave          Bel-Air Village       Makati City  METRO MANILA
# 12           Ave          Bel-Air Village       Makati City  METRO MANILA
# 13           Ave          Bel-Air Village       Makati City  METRO MANILA
# 14           Ave          Bel-Air Village       Makati City  METRO MANILA
# 15           Ave          Bel-Air Village       Makati City  METRO MANILA
# 16           Ave          Bel-Air Village       Makati City  METRO MANILA
# 17           Ave          Bel-Air Village       Makati City  METRO MANILA
# 18           Ave          Bel-Air Village       Makati City  METRO MANILA
# 19           Ave          Bel-Air Village       Makati City  METRO MANILA
# 20           Ave          Bel-Air Village       Makati City  METRO MANILA
# 21           Ave           Tutuban Center       Manila City  METRO MANILA
# 22           Ave                                Quezon City  METRO MANILA
# 23            St       San Miguel Village       Manila City  METRO MANILA
# 24            St       San Miguel Village       Manila City  METRO MANILA
# 25            St       San Miguel Village       Manila City  METRO MANILA
# 26            St       San Miguel Village       Manila City  METRO MANILA
# 27           Ave                                Quezon City  METRO MANILA
# 28           Ave                                Quezon City  METRO MANILA
# 29           Ave                                Quezon City  METRO MANILA
# ...          ...                      ...               ...           ...
# 57770         Rd           Ortigas Center        Pasig City  METRO MANILA
# 57771         Rd           Ortigas Center        Pasig City  METRO MANILA
# 57772        Ave                              Caloocan City  METRO MANILA
# 57773         Rd                                 Pasay City  METRO MANILA
# 57774        Ave                                Makati City  METRO MANILA
# 57775        Ave                                Makati City  METRO MANILA
# 57776        Ave                                Makati City  METRO MANILA
# 57777        Ave                                Makati City  METRO MANILA
# 57778        Ave                                Makati City  METRO MANILA
# 57779        Ave                                Makati City  METRO MANILA
# 57780         St                                Makati City  METRO MANILA
# 57781         St                                Makati City  METRO MANILA
# 57782         St                                Makati City  METRO MANILA
# 57783         St                                Makati City  METRO MANILA
# 57784        Ave          Legaspi Village       Makati City  METRO MANILA
# 57785         Rd                                 Pasig City  METRO MANILA
# 57786         St        BEL-AIR 2 VILLAGE       Makati City  METRO MANILA
# 57787         St                                 Pasig City  METRO MANILA
# 57788         St                                 Pasig City  METRO MANILA
# 57789         St                                 Pasig City  METRO MANILA
# 57790         Rd                                 Pasig City  METRO MANILA
# 57791         St                                 Pasig City  METRO MANILA
# 57792         St                                 Pasig City  METRO MANILA
# 57793         St                                 Pasig City  METRO MANILA
# 57794        Ave                                Makati City  METRO MANILA
# 57795        Ave          Salcedo Village       Makati City  METRO MANILA
# 57796        Ave          Salcedo Village       Makati City  METRO MANILA
# 57797        Ave          Salcedo Village       Makati City  METRO MANILA
# 57798        Ave          Salcedo Village       Makati City  METRO MANILA
# 57799        Ave          Salcedo Village       Makati City  METRO MANILA
#
#       class_code class_desc acc_type
# 0                                 BR
# 1                                 BR
# 2                                 BR
# 3                                 BR
# 4                                 BR
# 5                                 GO
# 6                                 GO
# 7                                 GO
# 8                                 GO
# 9                                 GO
# 10                                GO
# 11                                GO
# 12                                GO
# 13                                GO
# 14                                GO
# 15                                GO
# 16                                GO
# 17                                GO
# 18                                GO
# 19                                GO
# 20                                GO
# 21                                BR
# 22                                GO
# 23                                GO
# 24                                GO
# 25                                GO
# 26                                GO
# 27                                GO
# 28                                GO
# 29                                GO
# ...          ...        ...      ...
# 57770                             BR
# 57771                             BR
# 57772                             BR
# 57773                             BR
# 57774                             BR
# 57775                             BR
# 57776                             BR
# 57777                             BR
# 57778                             BR
# 57779                             BR
# 57780                             BR
# 57781                             BR
# 57782                             BR
# 57783                             BR
# 57784                             BR
# 57785                             BR
# 57786                             BR
# 57787                             BR
# 57788                             BR
# 57789                             BR
# 57790                             BR
# 57791                             BR
# 57792                             BR
# 57793                             BR
# 57794                             BR
# 57795                             BR
# 57796                             BR
# 57797                             BR
# 57798                             BR
# 57799                             BR
#
# [57800 rows x 14 columns]

# %%
rr_crm=pd.DataFrame()
rr_crm['Areacode']=rr.mem_wstd.str.slice(0,-7)#.astype('int64')
rr_crm['Phone']=rr.mem_wstd.str.slice(-7)
rr_crm['name1']=rr.last_name
rr_crm['name2']=rr.first_name
rr_crm['SAM_BLDNAME']=rr.sam_bldname
rr_crm['SAM_STNMFR']=rr.sam_stnmfr
rr_crm['SAM_STNAME']=rr.sam_stname
rr_crm['SAM_STSUBT']=rr.sam_stsubt
rr_crm['sam_estate']=rr.sam_estate
rr_crm['City']=rr.distribution_code.str.split('  ',1).str.get(1).apply(lambda x : x.strip()).str.upper()
rr_crm['Province']=rr.distribution_code.str.split('  ',1).str.get(0).apply(lambda x : x.strip()).str.upper()
rr_crm['class_code']=""
rr_crm['class_desc']=""
rr_crm['acc_type']=rr.acc_type
rr_crm['Areacode']=rr_crm['Areacode'].astype('int64')

rr_crm.name1 = rr_crm.name1.apply(lambda x: titlecase(x) if x.isupper() else x)
rr_crm.name2 = rr_crm.name2.apply(lambda x: titlecase(x) if x.isupper() else x)
rr_crm.SAM_BLDNAME = rr_crm.SAM_BLDNAME.apply(lambda x: titlecase(x) if x.isupper() else x)
rr_crm.SAM_STNAME = rr_crm.SAM_STNAME.apply(lambda x: titlecase(x))
rr_crm.SAM_STSUBT = rr_crm.SAM_STSUBT.apply(lambda x: titlecase(x))
rr_crm.sam_estate = rr_crm.sam_estate.apply(lambda x: titlecase(x))
rr_crm.City = rr_crm.City.apply(lambda x: titlecase(x))
rr_crm.Province = rr_crm.Province.apply(lambda x: titlecase(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-3647cebec67e> in <module>()
#      23 rr_crm.sam_estate = rr_crm.sam_estate.apply(lambda x: titlecase(x))
#      24 rr_crm.City = rr_crm.City.apply(lambda x: titlecase(x))
# ---> 25 rr_crm.Province = rr_crm.Province.apply(lambda x: titlecase(x))
#
# /Users/ncolina/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    2235             values = lib.map_infer(values, boxer)
#    2236
# -> 2237         mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2238         if len(mapped) and isinstance(mapped[0], Series):
#    2239             from pandas.core.frame import DataFrame
#
# pandas/src/inference.pyx in pandas.lib.map_infer (pandas/lib.c:63043)()
#
# <ipython-input-11-3647cebec67e> in <lambda>(x)
#      23 rr_crm.sam_estate = rr_crm.sam_estate.apply(lambda x: titlecase(x))
#      24 rr_crm.City = rr_crm.City.apply(lambda x: titlecase(x))
# ---> 25 rr_crm.Province = rr_crm.Province.apply(lambda x: titlecase(x))
#
# /Users/ncolina/Documents/DPC_SO/functions/capitalization.pyc in titlecase(text)
#      42
#      43     """
# ---> 44     lines = re.split('[\r\n]+', text)
#      45     processed = []
#      46     for line in lines:
#
# /Users/ncolina/anaconda/lib/python2.7/re.pyc in split(pattern, string, maxsplit, flags)
#     169     """Split the source string by the occurrences of the pattern,
#     170     returning a list containing the resulting substrings."""
# --> 171     return _compile(pattern, flags).split(string, maxsplit)
#     172
#     173 def findall(pattern, string, flags=0):
#
# TypeError: expected string or buffer

# %%
import numpy as np
def or_call(crm):
    index=crm.duplicated(['name1','name2','City','Province','SAM_BLDNAME','SAM_STNAME'])
    skip=False
    for i in xrange(len(index)):
        if index.ix[i] == True:
            line=crm.ix[i]
            prev_line=crm.ix[i-1]
            try:
                next_line=crm.ix[i+1]
            except:
                pass
            line['SAM_BLDNAME']=''
            line['SAM_STNMFR']=''
            line['SAM_STNAME']=''
            line['SAM_STSUBT']=''
            line['sam_estate']=''
            line['PROVINCE']=''
            line['class_code']=''
            line['class_desc']=''
            #line['name1']=''
            #line['name2']=''
            if skip == False:
                prev_line['Phone']=str(prev_line.Phone)+'/'+str(line.Phone)
                line['Phone']=''

                if index.ix[i-1] == False and index.ix[i+1]==True:
                    next_line['City']='Or Call:'
                try:
                    if index.ix[i+1] == True:
                        skip =True
                    
                except:
                    pass
            else:
                skip = False
    crm['Phone'].replace('', np.nan, inplace=True)
    return  crm[crm.Phone.notnull()]

# %%
import csv 
with open('areacodes') as csvfile:
    reader= csv.reader(csvfile)
    codes = dict((rows[0],rows[1]) for rows in reader)

# %%
codes.get('bulacan')

# %%
print rr_crm.ix[5]
print rr_crm.ix[6]

# %%
rr_crm.duplicated('name1')

# %%
def or_call(crm):
    index=crm.duplicated(['name1','name2','City','Province','SAM_BLDNAME','SAM_STNAME'])
    skip=False
    for i in xrange(len(index)):
        if index.iloc[i] == True:
            line=crm.ix[i]
            prev_line=crm.ix[i-1]
            try:
                next_line=crm.ix[i+1]
            except:
                pass
            line['SAM_BLDNAME']=''
            line['SAM_STNMFR']=''
            line['SAM_STNAME']=''
            line['SAM_STSUBT']=''
            line['sam_estate']=''
            line['PROVINCE']=''
            line['class_code']=''
            line['class_desc']=''
            #line['name1']=''
            #line['name2']=''
            if skip == False:
                prev_line['Phone']=str(prev_line.Phone)+'/'+str(line.Phone)
                line['Phone']=np.nan

                if index.ix[i-1] == False and index.ix[i+1]==True:
                    next_line['City']='Or Call:'
                try:
                    if index.ix[i+1] == True:
                        skip =True
                except:
                    pass
            else:
                skip = False
    #crm['Phone'].replace('', np.nan, inplace=True)
    return  crm[crm.Phone.notnull()]
or_call(rr_crm)
# Out:
# /Users/ncolina/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ncolina/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ncolina/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ncolina/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ncolina/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ncolina/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ncolina/anaconda/lib/python2.7/site-packages/pandas/core/series.py:704: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.loc[key] = value
# /Users/ncolina/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ncolina/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ncolina/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ncolina/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ncolina/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
str(open('small_words').read())

# %%
open('small_words').read().rstrip('\n')

# %%
import functions.interface_functions

# %%
import glob
import os
newest = min(glob.iglob('database_backups/*.hdf5'), key=os.path.getctime)

# %%
newest

# %%
rr.distribution_code.str.split('    ',1).str.get(1)

# %%
index=rr_crm.duplicated(['name1','name2','City','Province','SAM_BLDNAME','SAM_STNAME'])

# %%
range(len(index))

# %%
index[1]

# %%
index=rr_crm.duplicated(['name1','name2','City','Province','SAM_BLDNAME','SAM_STNAME'])

# %%
'dfdsf sdfsdfs        sdfsd'.split('s')

# %%
rr

# %%
x=8
x=x or 5
x

# %%
os.getlogin()

# %%
import csv
reader = csv.reader(open('config/input_format'))#,delimiter=',',quotechar='')
titles=reader.next()
widths=reader.next()

# %%
titles[0]

# %%
reader= csv.reader(open('config/input_format'),quoting=csv.QUOTE_NONNUMERIC)
lines=[]
for row in reader:
    print list(row)
names=lines[0]
widths=lines[1]

# %%
import ConfigParser
Config = ConfigParser.ConfigParser()
Config.read("config/input_format")
Config.read('config/areacodes')
def ConfigSectionMap(section):
    dict1 = {}
    options = Config.options(section)
    for option in options:
        try:
            dict1[option] = Config.get(section, option)
            if dict1[option] == -1:
                DebugPrint("skip: %s" % option)
        except:
            print("exception on %s!" % option)
            dict1[option] = None
    return dict1

# %%
Config.options('areacodes')
#ConfigSectionMap('input_format').keys()

# %%
ConfigSectionMap('areacodes')

# %%
import pandas as pd
import numpy as np
crm=pd.DataFrame(np.array([['AREACODE',10],['b',1],['c',None],['n',5]]))

# %%
crm.sort_values(by=0)
crm.sort_values(by=0).drop_duplicates(0,keep='last')
# Out:
#           0     1
# 0  AREACODE    10
# 1         b     1
# 2         c  None
# 3         n     5

# %%
OP= rr[rr.acc_type=='BR']
rr.loc[rr.account_no.isin(OP.account_no),'dir_code']=1
rr
# Out:
#       dir_code so_type sonumber  mem_wstd first_name  \
# 0            1                   27063050
# 1            1                   23983090
# 2            1                   28251854
# 3            1                   25562917
# 4            1                   26318181
# 5            1      10       10        10         10
# 6            1      10       10        10         10
# 7            1      10       10        10         10
# 8            1      10       10        10         10
# 9            1      10       10        10         10
# 10           1      10       10        10         10
# 11           1      10       10        10         10
# 12           1      10       10        10         10
# 13           1      10       10        10         10
# 14           1      10       10        10         10
# 15           1      10       10        10         10
# 16           1      10       10        10         10
# 17           1      10       10        10         10
# 18           1      10       10        10         10
# 19           1      10       10        10         10
# 20           1      10       10        10         10
# 21           1                   22563748
# 22           1      10       10        10         10
# 23           1      10       10        10         10
# 24           1      10       10        10         10
# 25           1      10       10        10         10
# 26           1      10       10        10         10
# 27           1      10       10        10         10
# 28           1      10       10        10         10
# 29           1      10       10        10         10
# ...        ...     ...      ...       ...        ...
# 57770        1                   29972967
# 57771        1                   29972965
# 57772        1                   23610820
# 57773        1                   28511803
# 57774        1                   25218942
# 57775        1                   28447568
# 57776        1                   25219132
# 57777        1                   25361557
# 57778        1                   25218937
# 57779        1                   28449394
# 57780        1                   25551456
# 57781        1                   28086187
# 57782        1                   28901164
# 57783        1                   28901165
# 57784        1                   28934723
# 57785        1                   25842303
# 57786        1                   24039887
# 57787        1                   24511647
# 57788        1                   22349409
# 57789        1                   22349597
# 57790        1                   25840630
# 57791        1                   22349041
# 57792        1                   26725101
# 57793        1                   22349185
# 57794        1                   28446178
# 57795        1                   28935958
# 57796        1                   28935960
# 57797        1                   28935956
# 57798        1                   28931693
# 57799        1                   28935937
#
#                                     last_name sam_city      sam_stname  \
# 0                                                 MAND            EDSA
# 1           "K" LINE LOGISTICS (PHILS.), INC.     PARQ    NINOY AQUINO
# 2           "K" LINE LOGISTICS (PHILS.), INC.     PARQ    NINOY AQUINO
# 3      "K" Line Maritime Training Corporation     PASY        CORALWAY
# 4                  (BANK OF THE PHIL ISLANDS)     MAND          UNITED
# 5                                          10       10              10
# 6                                          10       10              10
# 7                                          10       10              10
# 8                                          10       10              10
# 9                                          10       10              10
# 10                                         10       10              10
# 11                                         10       10              10
# 12                                         10       10              10
# 13                                         10       10              10
# 14                                         10       10              10
# 15                                         10       10              10
# 16                                         10       10              10
# 17                                         10       10              10
# 18                                         10       10              10
# 19                                         10       10              10
# 20                                         10       10              10
# 21           (LBC) EMT FORWARDING SERVICESINC     MANI       C M RECTO
# 22                                         10       10              10
# 23                                         10       10              10
# 24                                         10       10              10
# 25                                         10       10              10
# 26                                         10       10              10
# 27                                         10       10              10
# 28                                         10       10              10
# 29                                         10       10              10
# ...                                       ...      ...             ...
# 57770                   Zed Philippines, Inc.     PASI        SAPPHIRE
# 57771                   Zed Philippines, Inc.     PASI        SAPPHIRE
# 57772  Zenith International Philippines, Inc.     CALO             5TH
# 57773                      Zest Airways, Inc.     PASY        DOMESTIC
# 57774                       eCOPY CORPORATION     MAKT     ZOBEL ROXAS
# 57775                       eCOPY CORPORATION     MAKT   SEN GIL PUYAT
# 57776                       eCOPY CORPORATION     MAKT     ZOBEL ROXAS
# 57777                       eCOPY CORPORATION     MAKT     ZOBEL ROXAS
# 57778                       eCOPY CORPORATION     MAKT     ZOBEL ROXAS
# 57779                       eCOPY CORPORATION     MAKT   SEN GIL PUYAT
# 57780                              ePDS, Inc.     MAKT    PRIMO RIVERA
# 57781                              ePDS, Inc.     MAKT    PRIMO RIVERA
# 57782                              ePDS, Inc.     MAKT    PRIMO RIVERA
# 57783                              ePDS, Inc.     MAKT    PRIMO RIVERA
# 57784                                   ePLDT     MAKT           AYALA
# 57785                             ePLDT, Inc.     PASI          CANLEY
# 57786                             ePLDT, Inc.     MAKT  NICANOR GARCIA
# 57787                             ePLDT, Inc.     PASI         D FLORO
# 57788                             ePLDT, Inc.     PASI         D FLORO
# 57789                             ePLDT, Inc.     PASI         D FLORO
# 57790                             ePLDT, Inc.     PASI          CANLEY
# 57791                             ePLDT, Inc.     PASI         D FLORO
# 57792                             ePLDT, Inc.     PASI         D FLORO
# 57793                             ePLDT, Inc.     PASI         D FLORO
# 57794                    iPEOPLE INCORPORATED     MAKT   SEN GIL PUYAT
# 57795                   kgb Philippines, Inc.     MAKT           AYALA
# 57796                   kgb Philippines, Inc.     MAKT           AYALA
# 57797                   kgb Philippines, Inc.     MAKT           AYALA
# 57798                   kgb Philippines, Inc.     MAKT           AYALA
# 57799                   kgb Philippines, Inc.     MAKT           AYALA
#
#       sam_stsubt sam_stnmfr     ...      list_code acc_type old_wstd so_date  \
# 0            AVE                ...             PB       BR
# 1            AVE                ...             PB       BR
# 2            AVE                ...             PB       BR
# 3            DRV                ...             PB       BR
# 4             ST                ...             PB       BR
# 5             10         10     ...             10       GO
# 6             10         10     ...             10       GO
# 7             10         10     ...             10       GO
# 8             10         10     ...             10       GO
# 9             10         10     ...             10       GO
# 10            10         10     ...             10       GO
# 11            10         10     ...             10       GO
# 12            10         10     ...             10       GO
# 13            10         10     ...             10       GO
# 14            10         10     ...             10       GO
# 15            10         10     ...             10       GO
# 16            10         10     ...             10       GO
# 17            10         10     ...             10       GO
# 18            10         10     ...             10       GO
# 19            10         10     ...             10       GO
# 20            10         10     ...             10       GO
# 21           AVE                ...             PB       BR
# 22            10         10     ...             10       GO
# 23            10         10     ...             10       GO
# 24            10         10     ...             10       GO
# 25            10         10     ...             10       GO
# 26            10         10     ...             10       GO
# 27            10         10     ...             10       GO
# 28            10         10     ...             10       GO
# 29            10         10     ...             10       GO
# ...          ...        ...     ...            ...      ...      ...     ...
# 57770         RD                ...             PB       BR
# 57771         RD                ...             PB       BR
# 57772        AVE         78     ...             PB       BR
# 57773         RD                ...             PB       BR
# 57774        AVE       5837     ...             PB       BR
# 57775        AVE         65     ...             PB       BR
# 57776        AVE       5837     ...             PB       BR
# 57777        AVE       5837     ...             PB       BR
# 57778        AVE       5837     ...             PB       BR
# 57779        AVE         65     ...             PB       BR
# 57780         ST       2112     ...             PB       BR
# 57781         ST       2112     ...             PB       BR
# 57782         ST       2112     ...             PB       BR
# 57783         ST       2112     ...             PB       BR
# 57784        AVE       6752     ...             PB       BR
# 57785         RD                ...             PB       BR
# 57786         ST                ...             PB       BR
# 57787         ST                ...             PB       BR
# 57788         ST                ...             PB       BR
# 57789         ST                ...             PB       BR
# 57790         RD                ...             PB       BR
# 57791         ST                ...             PB       BR
# 57792         ST                ...             PB       BR
# 57793         ST                ...             PB       BR
# 57794        AVE        221     ...             PB       BR
# 57795        AVE       6819     ...             PB       BR
# 57796        AVE       6819     ...             PB       BR
# 57797        AVE       6819     ...             PB       BR
# 57798        AVE       6819     ...             PB       BR
# 57799        AVE       6819     ...             PB       BR
#
#       joint_user regulatory_id account_no  \
# 0                          PLD  653096224
# 1                          PLD  652611419
# 2                          PLD    6782191
# 3                          PLD  195847231
# 4                          PLD    6274366
# 5                          PLD     930393
# 6                          PLD   85034774
# 7                          PLD   30236157
# 8                          PLD     123285
# 9                          PLD   81940932
# 10                         PLD    1043633
# 11                         PLD   26066522
# 12                         PLD   25742176
# 13                         PLD      47864
# 14                         PLD    1108638
# 15                         PLD   25742265
# 16                         PLD    1108786
# 17                         PLD   27153208
# 18                         PLD    1863061
# 19                         PLD    1187090
# 20                         PLD    1033891
# 21                         PLD  106713561
# 22                         PLD  153213127
# 23                         PLD   85540858
# 24                         PLD   85540823
# 25                         PLD     158607
# 26                         PLD    1267590
# 27                         PLD  153213224
# 28                         PLD  153213216
# 29                         PLD   96287860
# ...          ...           ...        ...
# 57770                      PLD  653042280
# 57771                      PLD  653042280
# 57772                      PLD  651006643
# 57773                      PLD  106977917
# 57774                      PLD  173005563
# 57775                      PLD  603368525
# 57776                      PLD  173005385
# 57777                      PLD  102217462
# 57778                      PLD  173005229
# 57779                      PLD  603368584
# 57780                      PLD  651502462
# 57781                      PLD  652168728
# 57782                      PLD  651854849
# 57783                      PLD  651854865
# 57784                      PLD  188319181
# 57785                      PLD  651952212
# 57786                      PLD  652219896
# 57787                      PLD  651734150
# 57788                      PLD  651734134
# 57789                      PLD  651734142
# 57790                      PLD  651952204
# 57791                      PLD  651734088
# 57792                      PLD  124223636
# 57793                      PLD  651734118
# 57794                      PLD  651539919
# 57795                      PLD  153087520
# 57796                      PLD  153690820
# 57797                      PLD  153087512
# 57798                      PLD  153087423
# 57799                      PLD  153087490
#
#                                     distribution_code           src  \
# 0      METRO MANILA                  MANDALUYONG CITY  BIGBANG1.txt
# 1        METRO MANILA                  PARANAQUE CITY  BIGBANG1.txt
# 2        METRO MANILA                  PARANAQUE CITY  BIGBANG1.txt
# 3            METRO MANILA                  PASAY CITY  BIGBANG1.txt
# 4      METRO MANILA                  MANDALUYONG CITY  BIGBANG1.txt
# 5           METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 6           METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 7           METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 8           METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 9           METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 10          METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 11          METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 12          METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 13          METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 14          METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 15          METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 16          METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 17          METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 18          METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 19          METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 20          METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 21          METRO MANILA                  MANILA CITY  BIGBANG1.txt
# 22          METRO MANILA                  QUEZON CITY  BIGBANG1.txt
# 23          METRO MANILA                  MANILA CITY  BIGBANG1.txt
# 24          METRO MANILA                  MANILA CITY  BIGBANG1.txt
# 25          METRO MANILA                  MANILA CITY  BIGBANG1.txt
# 26          METRO MANILA                  MANILA CITY  BIGBANG1.txt
# 27          METRO MANILA                  QUEZON CITY  BIGBANG1.txt
# 28          METRO MANILA                  QUEZON CITY  BIGBANG1.txt
# 29          METRO MANILA                  QUEZON CITY  BIGBANG1.txt
# ...                                               ...           ...
# 57770        METRO MANILA                  PASIG CITY  BIGBANG1.txt
# 57771        METRO MANILA                  PASIG CITY  BIGBANG1.txt
# 57772     METRO MANILA                  CALOOCAN CITY  BIGBANG1.txt
# 57773        METRO MANILA                  PASAY CITY  BIGBANG1.txt
# 57774       METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 57775       METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 57776       METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 57777       METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 57778       METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 57779       METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 57780       METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 57781       METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 57782       METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 57783       METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 57784       METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 57785        METRO MANILA                  PASIG CITY  BIGBANG1.txt
# 57786       METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 57787        METRO MANILA                  PASIG CITY  BIGBANG1.txt
# 57788        METRO MANILA                  PASIG CITY  BIGBANG1.txt
# 57789        METRO MANILA                  PASIG CITY  BIGBANG1.txt
# 57790        METRO MANILA                  PASIG CITY  BIGBANG1.txt
# 57791        METRO MANILA                  PASIG CITY  BIGBANG1.txt
# 57792        METRO MANILA                  PASIG CITY  BIGBANG1.txt
# 57793        METRO MANILA                  PASIG CITY  BIGBANG1.txt
# 57794       METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 57795       METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 57796       METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 57797       METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 57798       METRO MANILA                  MAKATI CITY  BIGBANG1.txt
# 57799       METRO MANILA                  MAKATI CITY  BIGBANG1.txt
#
#       so_rangedate
# 0       2016/07/27
# 1       2016/07/27
# 2       2016/07/27
# 3       2016/07/27
# 4       2016/07/27
# 5       2016/07/27
# 6       2016/07/27
# 7       2016/07/27
# 8       2016/07/27
# 9       2016/07/27
# 10      2016/07/27
# 11      2016/07/27
# 12      2016/07/27
# 13      2016/07/27
# 14      2016/07/27
# 15      2016/07/27
# 16      2016/07/27
# 17      2016/07/27
# 18      2016/07/27
# 19      2016/07/27
# 20      2016/07/27
# 21      2016/07/27
# 22      2016/07/27
# 23      2016/07/27
# 24      2016/07/27
# 25      2016/07/27
# 26      2016/07/27
# 27      2016/07/27
# 28      2016/07/27
# 29      2016/07/27
# ...            ...
# 57770   2016/07/27
# 57771   2016/07/27
# 57772   2016/07/27
# 57773   2016/07/27
# 57774   2016/07/27
# 57775   2016/07/27
# 57776   2016/07/27
# 57777   2016/07/27
# 57778   2016/07/27
# 57779   2016/07/27
# 57780   2016/07/27
# 57781   2016/07/27
# 57782   2016/07/27
# 57783   2016/07/27
# 57784   2016/07/27
# 57785   2016/07/27
# 57786   2016/07/27
# 57787   2016/07/27
# 57788   2016/07/27
# 57789   2016/07/27
# 57790   2016/07/27
# 57791   2016/07/27
# 57792   2016/07/27
# 57793   2016/07/27
# 57794   2016/07/27
# 57795   2016/07/27
# 57796   2016/07/27
# 57797   2016/07/27
# 57798   2016/07/27
# 57799   2016/07/27
#
# [57800 rows x 25 columns]

# %%
product=pd.read_excel('Company_Class.xlsx')
product.name1=product.name1.str.upper()
#product.Phone=5361557
rr_crm.name1=rr_crm.name1.str.upper()
rr_crm=rr_crm.drop_duplicates('Phone')

# %%
rr_crm.drop_duplicates('Phone').Phone=3
# Out:
# /Users/ncolina/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:2698: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
pd.merge(rr_crm,product, on=['Phone'], how='left')
# Out:
#    AREACODE  Phone  name1_x name2_x    SAM_BLDNAME SAM_STNMFR SAM_STNAME  \
# 0       NaN     10      NaN          SM MEGAMALL A                  EDSA
#
#   SAM_STSUBT sam_estate              City PROVINCE class_code_x class_desc  \
# 0        AVE             MANDALUYONG CITY      ncr
#
#   acc_type  Areacode              name1_y name2_y           Product  \
# 0       BR         2  S C TAN EXPORT CORP     NaN  MLABUS2016_MNLYP
#
#    class_code_y
# 0        104376

# %%
rr_crm['Phone']
# Out:
# 0        10
# 1        10
# 2        10
# 3        10
# 4        10
# 5        10
# 6        10
# 7        10
# 8        10
# 9        10
# 10       10
# 11       10
# 12       10
# 13       10
# 14       10
# 15       10
# 16       10
# 17       10
# 18       10
# 19       10
# 20       10
# 21       10
# 22       10
# 23       10
# 24       10
# 25       10
# 26       10
# 27       10
# 28       10
# 29       10
#          ..
# 57770    10
# 57771    10
# 57772    10
# 57773    10
# 57774    10
# 57775    10
# 57776    10
# 57777    10
# 57778    10
# 57779    10
# 57780    10
# 57781    10
# 57782    10
# 57783    10
# 57784    10
# 57785    10
# 57786    10
# 57787    10
# 57788    10
# 57789    10
# 57790    10
# 57791    10
# 57792    10
# 57793    10
# 57794    10
# 57795    10
# 57796    10
# 57797    10
# 57798    10
# 57799    10
# Name: Phone, dtype: int64

# %%
product.Phone=10
product=product.drop_duplicates('Phone')

# %%
Config.read("config/crm_format")

Config.options('crm_format')
# Out:
# ---------------------------------------------------------------------------
# ParsingError                              Traceback (most recent call last)
# <ipython-input-263-9d7e5892a000> in <module>()
# ----> 1 Config.read("config/crm_format")
#       2
#       3 Config.options('crm_format')
#
# /Users/ncolina/anaconda/lib/python2.7/ConfigParser.pyc in read(self, filenames)
#     303             except IOError:
#     304                 continue
# --> 305             self._read(fp, filename)
#     306             fp.close()
#     307             read_ok.append(filename)
#
# /Users/ncolina/anaconda/lib/python2.7/ConfigParser.pyc in _read(self, fp, fpname)
#     544         # if any parsing errors occurred, raise an exception
#     545         if e:
# --> 546             raise e
#     547
#     548         # join the multi-line values collected while reading
#
# ParsingError: File contains parsing errors: config/crm_format
# 	[line  2]: 'Areacode\n'
# 	[line  3]: 'Phone\n'
# 	[line  4]: 'name1\n'
# 	[line  5]: 'name2\n'
# 	[line  6]: 'SAM_BLDNAME\n'
# 	[line  7]: 'SAM_STNMFR\n'
# 	[line  8]: 'SAM_STNAME\n'
# 	[line  9]: 'SAM_STSUBT\n'
# 	[line 10]: 'sam_estate\n'
# 	[line 11]: 'City\n'
# 	[line 12]: 'Province\n'
# 	[line 13]: 'class_code\n'
# 	[line 14]: 'acc_type\n'

# %%
classes=pd.read_excel('Company_Class.xlsx')
classes_up=classes
classes_up.name1=classes_up.name1.str.upper()
        #remove columns not used to find classes here
classes_up = classes_up.drop(['name2','Product'], 1)
classes_up
#database_up=database.name1.str.upper(inplace=True)
#database_coded=pd.merge(database_up,classes_up, on=['Areacode','Phone','name1'], how='left')
#database_coded.name1=database.name1
# Out:
#     Areacode    Phone                                             name1  \
# 0          2  7275767                               S C TAN EXPORT CORP
# 1          2  5232306                           ARMAK ABRASIVE PRODUCTS
# 2          2  5311805            CORD CHEMICAL PHILIPPINES INCORPORATED
# 3          2  6384880                                   GE-MA MARKETING
# 4          2  5213883                           ROYAL GLOBE CORPORATION
# 5          2  8102991                       SHIMEX TRADING INCORPORATED
# 6          2  4214883                                 TRANSPO SALES INC
# 7          2  9958937                       TRANSPO SALES INTERNATIONAL
# 8          2  2942655                               COYNE MERCHANDISING
# 9          2  8211789                                  HANDOG MARKETING
# 10         2  8749929                                        PAMELA GAS
# 11         2  9321850                          JEA STEEL INDUSTRIES INC
# 12         2  8448441                                   CHAN C BROS INC
# 13         2  7249312                     MODERN ART SUPPLY CORPORATION
# 14         2  7349845                   PHILIPPINES AUTO SUPPLY COMPANY
# 15         2  8943827                            ACTUARIAL ADVISERS INC
# 16         2  8866552                     EM ZALAMEA ACTUARIAL SERVICES
# 17         2  8937107                EZ HOUSING DEVELOPMENT CORPORATION
# 18         2  9217686                  CHARTERED ADJUSTERS INCORPORATED
# 19         2  2421661                       D' EXPONENT SURVEYORS & ADJ
# 20         2  2416777                DELA MERCED ADJUSTMENT CORPORATION
# 21         2  7323486                         DOMINICAN HILLS MARKETING
# 22         2  8174158              MANILA ADJUSTERS & SURVEYORS COMPANY
# 23         2  2419401         TAN GATUE ADJUSTMENT COMPANY INCORPORATED
# 24         2  3584126                              BIG BANNERS GRAPHICS
# 25         2  8891129                                 CITIMAX GROUP INC
# 26         2  8161186                                   AGCHEM MFG CORP
# 27         2  8189367                    TRANS WORLD AGRO PRODUCTS CORP
# 28         2  8233043                  YABUT L T AGRO INDUSTRIAL SUPPLY
# 29         2  8190998                   ECJ & SONS AGRICULTURAL ENT INC
# ..       ...      ...                                               ...
# 39         2  8138940                    DELTA-T DEV LOGICAL TECHNIQUES
# 40         2  9115577                                    ENERTHRUST INC
# 41         2  9138860              JES SERVICE SPECIALISTS INCORPORATED
# 42         2  2854633                         SPIRAL GROUP INCORPORATED
# 43         2  8217441                                  TEMP EXPRESS INC
# 44         2  7763498              THERMOMETRIC INDUSTRIAL INCORPORATED
# 45         2  5272679                     MOVERS & MANAGERS CORPORATION
# 46         2  8547921                       ORIENT AVIATION CORPORATION
# 47         2  6712102                         3 SUN TRADERS CORPORATION
# 48         2  9839327                                ALCOPHIL METAL INC
# 49         2  7332174              ALUMINUM POWER MARKETING CORPORATION
# 50         2  3722420              ANITA GLASS AND ALUMINUM ENTERPRISES
# 51         2  6412573                         ARLO ALUMINUM COMPANY INC
# 52         2  2885101                 ASIATIC ALUMINUM PRODUCTS COMPANY
# 53         2  8323933                   CROWN ALUMINUM AND GLASS SUPPLY
# 54         2  8732773          CRYSTALITE ALUMINUM AND GLASSENTERPRISES
# 55         2  3646810                 FORTITUDE INDUSTRIES INCORPORATED
# 56         2  7417409                     GEM ALUMINUM AND GLASS CENTER
# 57         2  5311782                        KING FRED ALUMINUM & GLASS
# 58         2  7250091                                 K-MAR ENTERPRISES
# 59         2  5310891        NEW TOPBEST LUMBER CONSTRUCTION SUPPLY INC
# 60         2  3617776                    NITOO ENTERPRISES INCORPORATED
# 61         2  7217089                                PAGENT ENTERPRISES
# 62         2  2772717                              PERMAWIN ENTERPRISES
# 63         2  9388953                                           PILARES
# 64         2  7164534               QUINTA TRADING COMPANY INCORPORATED
# 65         2  3710329  ROOSEVELT ALUMINUM PRODUCTS COMPANY INCORPORATED
# 66         2  8253076                SEVEN STAR ALUMINUM & GLASS SUPPLY
# 67         2  7317169                      STANZA ALUMINUM & GLASS CORP
# 68         2  5311150               SWAN ALUMINUM & ALLIED PRODUCTS INC
#
#       class_code
# 0         104376
# 1         104377
# 2         104377
# 3         104377
# 4         104377
# 5         104377
# 6         104377
# 7         104377
# 8         104384
# 9         104384
# 10        104384
# 11        104391
# 12        104392
# 13        104392
# 14        104392
# 15        104393
# 16        104393
# 17        104393
# 18        104393
# 19        104393
# 20        104393
# 21        104393
# 22        104393
# 23        104393
# 24        104423
# 25        104431
# 26        104433
# 27        104433
# 28        104433
# 29        104434
# ..           ...
# 39        104453
# 40        104453
# 41        104453
# 42        104453
# 43        104453
# 44        104453
# 45  201604050001
# 46        104481
# 47        104491
# 48        104491
# 49        104491
# 50        104491
# 51        104491
# 52        104491
# 53        104491
# 54        104491
# 55        104491
# 56        104491
# 57        104491
# 58        104491
# 59        104491
# 60        104491
# 61        104491
# 62        104491
# 63        104491
# 64        104491
# 65        104491
# 66        104491
# 67        104491
# 68        104491
#
# [69 rows x 4 columns]

# %%
classes.Phone.iloc[5]=None

# %%
len(classes.index)
# Out:
# 69

# %%
classes.append()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-404-0c4b5b0e27c2> in <module>()
# ----> 1 classes.append()
#
# TypeError: append() takes at least 2 arguments (1 given)

# %%
classes
# Out:
#     Areacode    Phone                                             name1  \
# 0          2  7275767                               S C TAN EXPORT CORP
# 1          2  5232306                           ARMAK ABRASIVE PRODUCTS
# 2          2  5311805            CORD CHEMICAL PHILIPPINES INCORPORATED
# 3          2                                            GE-MA MARKETING
# 4          2  5213883                           ROYAL GLOBE CORPORATION
# 5          2     None                       SHIMEX TRADING INCORPORATED
# 6          2  4214883                                 TRANSPO SALES INC
# 7          2  9958937                       TRANSPO SALES INTERNATIONAL
# 8          2  2942655                               COYNE MERCHANDISING
# 9          2  8211789                                  HANDOG MARKETING
# 10         2  8749929                                        PAMELA GAS
# 11         2  9321850                          JEA STEEL INDUSTRIES INC
# 12         2  8448441                                   CHAN C BROS INC
# 13         2  7249312                     MODERN ART SUPPLY CORPORATION
# 14         2  7349845                   PHILIPPINES AUTO SUPPLY COMPANY
# 15         2  8943827                            ACTUARIAL ADVISERS INC
# 16         2  8866552                     EM ZALAMEA ACTUARIAL SERVICES
# 17         2  8937107                EZ HOUSING DEVELOPMENT CORPORATION
# 18         2  9217686                  CHARTERED ADJUSTERS INCORPORATED
# 19         2  2421661                       D' EXPONENT SURVEYORS & ADJ
# 20         2  2416777                DELA MERCED ADJUSTMENT CORPORATION
# 21         2  7323486                         DOMINICAN HILLS MARKETING
# 22         2  8174158              MANILA ADJUSTERS & SURVEYORS COMPANY
# 23         2  2419401         TAN GATUE ADJUSTMENT COMPANY INCORPORATED
# 24         2  3584126                              BIG BANNERS GRAPHICS
# 25         2  8891129                                 CITIMAX GROUP INC
# 26         2  8161186                                   AGCHEM MFG CORP
# 27         2  8189367                    TRANS WORLD AGRO PRODUCTS CORP
# 28         2  8233043                  YABUT L T AGRO INDUSTRIAL SUPPLY
# 29         2  8190998                   ECJ & SONS AGRICULTURAL ENT INC
# ..       ...      ...                                               ...
# 39         2  8138940                    DELTA-T DEV LOGICAL TECHNIQUES
# 40         2  9115577                                    ENERTHRUST INC
# 41         2  9138860              JES SERVICE SPECIALISTS INCORPORATED
# 42         2  2854633                         SPIRAL GROUP INCORPORATED
# 43         2  8217441                                  TEMP EXPRESS INC
# 44         2  7763498              THERMOMETRIC INDUSTRIAL INCORPORATED
# 45         2  5272679                     MOVERS & MANAGERS CORPORATION
# 46         2  8547921                       ORIENT AVIATION CORPORATION
# 47         2  6712102                         3 SUN TRADERS CORPORATION
# 48         2  9839327                                ALCOPHIL METAL INC
# 49         2  7332174              ALUMINUM POWER MARKETING CORPORATION
# 50         2  3722420              ANITA GLASS AND ALUMINUM ENTERPRISES
# 51         2  6412573                         ARLO ALUMINUM COMPANY INC
# 52         2  2885101                 ASIATIC ALUMINUM PRODUCTS COMPANY
# 53         2  8323933                   CROWN ALUMINUM AND GLASS SUPPLY
# 54         2  8732773          CRYSTALITE ALUMINUM AND GLASSENTERPRISES
# 55         2  3646810                 FORTITUDE INDUSTRIES INCORPORATED
# 56         2  7417409                     GEM ALUMINUM AND GLASS CENTER
# 57         2  5311782                        KING FRED ALUMINUM & GLASS
# 58         2  7250091                                 K-MAR ENTERPRISES
# 59         2  5310891        NEW TOPBEST LUMBER CONSTRUCTION SUPPLY INC
# 60         2  3617776                    NITOO ENTERPRISES INCORPORATED
# 61         2  7217089                                PAGENT ENTERPRISES
# 62         2  2772717                              PERMAWIN ENTERPRISES
# 63         2  9388953                                           PILARES
# 64         2  7164534               QUINTA TRADING COMPANY INCORPORATED
# 65         2  3710329  ROOSEVELT ALUMINUM PRODUCTS COMPANY INCORPORATED
# 66         2  8253076                SEVEN STAR ALUMINUM & GLASS SUPPLY
# 67         2  7317169                      STANZA ALUMINUM & GLASS CORP
# 68         2  5311150               SWAN ALUMINUM & ALLIED PRODUCTS INC
#
#       name2           Product    class_code
# 0       NaN  MLABUS2016_MNLYP        104376
# 1       NaN  MLABUS2016_MNLYP        104377
# 2       NaN  MLABUS2016_MNLYP        104377
# 3       NaN  MLABUS2016_MNLYP        104377
# 4       NaN  MLABUS2016_MNLYP        104377
# 5       NaN  MLABUS2016_MNLYP        104377
# 6       NaN  MLABUS2016_MNLYP        104377
# 7       NaN  MLABUS2016_MNLYP        104377
# 8       NaN  MLABUS2016_MNLYP        104384
# 9       NaN  MLABUS2016_MNLYP        104384
# 10      NaN  MLABUS2016_MNLYP        104384
# 11      NaN  MLABUS2016_MNLYP        104391
# 12      NaN  MLABUS2016_MNLYP        104392
# 13      NaN  MLABUS2016_MNLYP        104392
# 14      NaN  MLABUS2016_MNLYP        104392
# 15      NaN  MLABUS2016_MNLYP        104393
# 16      NaN  MLABUS2016_MNLYP        104393
# 17      NaN  MLABUS2016_MNLYP        104393
# 18      NaN  MLABUS2016_MNLYP        104393
# 19      NaN  MLABUS2016_MNLYP        104393
# 20      NaN  MLABUS2016_MNLYP        104393
# 21      NaN  MLABUS2016_MNLYP        104393
# 22      NaN  MLABUS2016_MNLYP        104393
# 23      NaN  MLABUS2016_MNLYP        104393
# 24      NaN  MLABUS2016_MNLYP        104423
# 25      NaN  MLABUS2016_MNLYP        104431
# 26      NaN  MLABUS2016_MNLYP        104433
# 27      NaN  MLABUS2016_MNLYP        104433
# 28      NaN  MLABUS2016_MNLYP        104433
# 29      NaN  MLABUS2016_MNLYP        104434
# ..      ...               ...           ...
# 39      NaN  MLABUS2016_MNLYP        104453
# 40      NaN  MLABUS2016_MNLYP        104453
# 41      NaN  MLABUS2016_MNLYP        104453
# 42      NaN  MLABUS2016_MNLYP        104453
# 43      NaN  MLABUS2016_MNLYP        104453
# 44      NaN  MLABUS2016_MNLYP        104453
# 45      NaN  MLABUS2016_MNLYP  201604050001
# 46      NaN  MLABUS2016_MNLYP        104481
# 47      NaN  MLABUS2016_MNLYP        104491
# 48      NaN  MLABUS2016_MNLYP        104491
# 49      NaN  MLABUS2016_MNLYP        104491
# 50      NaN  MLABUS2016_MNLYP        104491
# 51      NaN  MLABUS2016_MNLYP        104491
# 52      NaN  MLABUS2016_MNLYP        104491
# 53      NaN  MLABUS2016_MNLYP        104491
# 54      NaN  MLABUS2016_MNLYP        104491
# 55      NaN  MLABUS2016_MNLYP        104491
# 56      NaN  MLABUS2016_MNLYP        104491
# 57      NaN  MLABUS2016_MNLYP        104491
# 58      NaN  MLABUS2016_MNLYP        104491
# 59      NaN  MLABUS2016_MNLYP        104491
# 60      NaN  MLABUS2016_MNLYP        104491
# 61      NaN  MLABUS2016_MNLYP        104491
# 62      NaN  MLABUS2016_MNLYP        104491
# 63  Nicanor  MLABUS2016_MNLYP        104491
# 64      NaN  MLABUS2016_MNLYP        104491
# 65      NaN  MLABUS2016_MNLYP        104491
# 66      NaN  MLABUS2016_MNLYP        104491
# 67      NaN  MLABUS2016_MNLYP        104491
# 68      NaN  MLABUS2016_MNLYP        104491
#
# [69 rows x 6 columns]

# %%
rr_crm=rr_crm[rr_crm.acc_type=='BR']
acc_type="BR"
product=pd.read_excel('Product_Lookup.xlsx')
product=product[product.acc_type == acc_type]
product=product.drop('acc_type',1)
product.rename(columns={'PROVINCE': 'Province', 'AREACODE': 'Areacode','PRODUCT SECTION':'Product'}, inplace=True)
#product.Province=product.Province.apply(lambda x : titlecase(x)
pd.merge(rr_crm,product, on=['Province','Areacode'], how='inner')
# Out:
# Empty DataFrame
# Columns: [Areacode, Phone, name1, name2, SAM_BLDNAME, SAM_STNMFR, SAM_STNAME, SAM_STSUBT, sam_estate, City, Province, class_code, class_desc, acc_type, Product]
# Index: []

# %%
product
# Out:
#      Areacode                 Province                Product
# 2          62           ZAMBOANGA_CITY   ZAMBO2016_ZAMBOCTYWP
# 5          65      ZAMBOANGA DEL NORTE      ZAMBO2016_ZAMDNWP
# 8          62        ZAMBOANGA DEL SUR      ZAMBO2016_ZAMDSWP
# 11         62        ZAMBOANGA SIBUGAY     ZAMBO2016_ZAMSIBWP
# 14         88         MISAMIS ORIENTAL     MSOCOR2016_MISORWP
# 17         88       MISAMIS OCCIDENTAL     MSOCOR2016_MISOCWP
# 20         63         MISAMIS ORIENTAL   PMARTL2016_PMMISORWP
# 23         63          LANAO DEL NORTE     PMARTL2016_LANAOWP
# 26         38                    BOHOL     BOHLEY2016_BOHOLWP
# 29         53                    LEYTE     BOHLEY2016_LEYTEWP
# 32         42               MARINDUQUE     PLMRMS2016_MARINWP
# 35         56                  MASBATE   PLMRMS2016_MASBATEWP
# 38         48                  PALAWAN   PLMRMS2016_PALAWANWP
# 41         52                    ALBAY     QUEZON2016_ALBAYWP
# 44         54          CAMARINES NORTE    QUEZON2016_CAMNORWP
# 47         54            CAMARINES SUR    QUEZON2016_CAMSURWP
# 50         52              CATANDUANES  QUEZON2016_CATANDNSWP
# 53         42                   QUEZON    QUEZON2016_QUEZONWP
# 56         56                 SORSOGON  QUEZON2016_SORSOGONWP
# 59         74                  BENGUET    BENMP2016_BENGUETWP
# 62         74        MOUNTAIN PROVINCE      BENMP2016_MPROVWP
# 65          2             METRO MANILA    MLABUS2016_MLABUSWP
# 68         34        NEGROS OCCIDENTAL     NEGROS2016_NEGOCWP
# 71         35          NEGROS ORIENTAL     NEGROS2016_NEGORWP
# 74         75               PANGASINAN     PNGLUN2016_PANGAWP
# 77         72                 LA UNION   PNGLUN2016_LAUNIONWP
# 80         77             ILOCOS NORTE     ILOCOS2016_ILOCNWP
# 83         77               ILOCOS SUR     ILOCOS2016_ILOCSWP
# 86         74                     ABRA      ILOCOS2016_ABRAWP
# 89         78                  CAGAYAN     CINV2016_CAGAYANWP
# ..        ...                      ...                    ...
# 119        64           NORTH COTABATO      GENSAN2016_NCOTWP
# 122        64           KIDAPAWAN CITY      GENSAN2016_MKTCWP
# 125        83                SARANGANI    GENSAN2016_SARANGWP
# 128        83           SOUTH COTABATO      GENSAN2016_SCOTWP
# 131        64           SULTAN KUDARAT   GENSAN2016_SKUDRATWP
# 134        84          DAVAO DEL NORTE    DAVAO2016_DAVAODNWP
# 137        82            DAVAO DEL SUR    DAVAO2016_DAVAODSWP
# 140        86          SURIGAO DEL SUR      DAVAO2016_SURDSWP
# 143        85     SBI AGUSAN DEL NORTE    PPHLCM2016_AGUSDNWP
# 146        85       SBI AGUSAN DEL SUR    PPHLCM2016_AGUSDSWP
# 149        88         PHILCOM BUKIDNON     PPHLCM2016_BUKIDWP
# 152        84     PH COMPOSTELA VALLEY   PPHLCM2016_CMPSTLAWP
# 155        84      SBI DAVAO DEL NORTE   PPHLCM2016_DAVAODNWP
# 158        87   PHILCOM DAVAO ORIENTAL   PPHLCM2016_DAVAOORWP
# 161        88     SBI MISAMIS ORIENTAL   PPHLCM2016_PPMISORWP
# 164        86    SBI SURIGAO DEL NORTE     PPHLCM2016_SURDNWP
# 167        86  PHILCOM SURIGAO DEL SUR     PPHLCM2016_SURDSWP
# 170        47                 ZAMBALES    BATZAM2016_BATAANWP
# 173        47                   BATAAN  BATZAM2016_ZAMBALESWP
# 176        33                   ILOILO    ILOCAP2016_ILOILOWP
# 179        36                    CAPIZ     ILOCAP2016_CAPIZWP
# 182        46                   CAVITE    CAVITE2016_CAVITEWP
# 185         2                   CAVITE  CAVITE2016_CAVITE02WP
# 188        49                   LAGUNA    LAGUNA2016_LAGUNAWP
# 191         2                   LAGUNA  LAGUNA2016_LAGUNA02WP
# 194        43                 BATANGAS  BATNGS2016_BATANGASWP
# 197        43       OCCIDENTAL MINDORO      BATNGS2016_OCCMWP
# 200         2                    RIZAL      RIZAL2016_RIZALWP
# 203        45                 PAMPANGA  PMPTLC2016_PAMPANGAWP
# 206        45                   TARLAC    PMPTLC2016_TARLACWP
#
# [69 rows x 3 columns]

# %%
rr_crm
# Out:
#        Areacode    Phone                                            name1  \
# 0             2  7063050
# 1             2  3983090                "K" Line Logistics (Phils.), Inc.
# 2             2  8251854                "K" Line Logistics (Phils.), Inc.
# 3             2  5562917           "K" Line Maritime Training Corporation
# 4             2  6318181                       (Bank of the Phil Islands)
# 5             2  8967916          (Department of Trade and Industrybsmbd)
# 6             2  8975554            (Department of Trade and Industrycic)
# 7             2  8908907            (Department of Trade and Industryipr)
# 8             2  8904951            (Department of Trade and Industryoop)
# 9             2  8971719          (Department of Trade and Industryticci)
# 10            2  8904857                   (Dept of Trade & Industryhrds)
# 11            2  8905123  (Dept of Trade & Industryofcof Special Concern)
# 12            2  8959460                    (Dept of Trade & Industryopr)
# 13            2  8967889                    (Dept of Trade & Industryopr)
# 14            2  8971243                    (Dept of Trade & Industryopr)
# 15            2  8953995                    (Dept of Trade & Industrypro)
# 16            2  8958133                    (Dept of Trade & Industrypro)
# 17            2  8904517                    (Dept of Trade & Industrypro)
# 18            2  8953558                    (Dept of Trade & Industrypro)
# 19            2  8904747                 (Dept of Trade and Industryftsc)
# 20            2  8901302                 (Dept of Trade and Industryncac)
# 21            2  2563748                 (Lbc) Emt Forwarding Servicesinc
# 22            2  3747268               (Rp) Dept of Budget and Department
# 23            2  7361230               (Rp) Dept of Budget and Department
# 24            2  7361234               (Rp) Dept of Budget and Department
# 25            2  7361284               (Rp) Dept of Budget and Department
# 26            2  7361285               (Rp) Dept of Budget and Department
# 27            2  3747270               (Rp) Dept of Budget and Department
# 28            2  3747269               (Rp) Dept of Budget and Department
# 29            2  9261065       (Rp) Housing and Land Use Regulatory Board
# ...         ...      ...                                              ...
# 57770         2  9972967                            Zed Philippines, Inc.
# 57771         2  9972965                            Zed Philippines, Inc.
# 57772         2  3610820           Zenith International Philippines, Inc.
# 57773         2  8511803                               Zest Airways, Inc.
# 57774         2  5218942                                eCOPY CORPORATION
# 57775         2  8447568                                eCOPY CORPORATION
# 57776         2  5219132                                eCOPY CORPORATION
# 57777         2  5361557                                eCOPY CORPORATION
# 57778         2  5218937                                eCOPY CORPORATION
# 57779         2  8449394                                eCOPY CORPORATION
# 57780         2  5551456                                       ePDS, Inc.
# 57781         2  8086187                                       ePDS, Inc.
# 57782         2  8901164                                       ePDS, Inc.
# 57783         2  8901165                                       ePDS, Inc.
# 57784         2  8934723                                            ePLDT
# 57785         2  5842303                                      ePLDT, Inc.
# 57786         2  4039887                                      ePLDT, Inc.
# 57787         2  4511647                                      ePLDT, Inc.
# 57788         2  2349409                                      ePLDT, Inc.
# 57789         2  2349597                                      ePLDT, Inc.
# 57790         2  5840630                                      ePLDT, Inc.
# 57791         2  2349041                                      ePLDT, Inc.
# 57792         2  6725101                                      ePLDT, Inc.
# 57793         2  2349185                                      ePLDT, Inc.
# 57794         2  8446178                             iPEOPLE INCORPORATED
# 57795         2  8935958                            kgb Philippines, Inc.
# 57796         2  8935960                            kgb Philippines, Inc.
# 57797         2  8935956                            kgb Philippines, Inc.
# 57798         2  8931693                            kgb Philippines, Inc.
# 57799         2  8935937                            kgb Philippines, Inc.
#
#       name2                     SAM_BLDNAME SAM_STNMFR      SAM_STNAME  \
# 0                             Sm Megamall A                       Edsa
# 1                   Oyster Complex Building               Ninoy Aquino
# 2                                                         Ninoy Aquino
# 3                           K-Line Building                   Coralway
# 4                  Mayflower Plaza Building                     United
# 5                              Dti Building        361   Sen Gil Puyat
# 6                              Dti Building        361   Sen Gil Puyat
# 7                              Dti Building        361   Sen Gil Puyat
# 8            Industry & Investment Building        385   Sen Gil Puyat
# 9                               Lc Building        375   Sen Gil Puyat
# 10                             Dti Building              Sen Gil Puyat
# 11             Board of Investment Building        385   Sen Gil Puyat
# 12                             Dti Building        361   Sen Gil Puyat
# 13           Industry & Investment Building        385   Sen Gil Puyat
# 14           Industry & Investment Building        385   Sen Gil Puyat
# 15           Industry & Investment Building        385   Sen Gil Puyat
# 16           Industry & Investment Building        385   Sen Gil Puyat
# 17           Industry & Investment Building        385   Sen Gil Puyat
# 18           Industry & Investment Building        385   Sen Gil Puyat
# 19                       New Solid Building        357   Sen Gil Puyat
# 20                             Dti Building              Sen Gil Puyat
# 21                    TUTUBAN CENTER MALL 1                  C M Recto
# 22                   Ben-Lor Annex Building       1184          Quezon
# 23                           DBM BUILDING 1        755      Gen Solano
# 24                           DBM BUILDING 1        755      Gen Solano
# 25                           DBM BUILDING 1        755      Gen Solano
# 26                           DBM BUILDING 1        755      Gen Solano
# 27                   Ben-Lor Annex Building       1184          Quezon
# 28                   Ben-Lor Annex Building       1184          Quezon
# 29                       Sunnymede Building       1614          Quezon
# ...     ...                             ...        ...             ...
# 57770                   Marco Polo Building                   Sapphire
# 57771                   Marco Polo Building                   Sapphire
# 57772                                               78             5TH
# 57773                      Domestic Airport                   Domestic
# 57774                       Cygnet Building       5837     Zobel Roxas
# 57775                                               65   Sen Gil Puyat
# 57776                       Cygnet Building       5837     Zobel Roxas
# 57777                                             5837     Zobel Roxas
# 57778                       Cygnet Building       5837     Zobel Roxas
# 57779                                               65   Sen Gil Puyat
# 57780                                             2112    Primo Rivera
# 57781                                             2112    Primo Rivera
# 57782                                             2112    Primo Rivera
# 57783                                             2112    Primo Rivera
# 57784                   L v Locsin Building       6752           Ayala
# 57785                          Idc Building                     Canley
# 57786                          Spi Building             Nicanor Garcia
# 57787                          Idc Building                    D Floro
# 57788                          Idc Building                    D Floro
# 57789                          Idc Building                    D Floro
# 57790                          Idc Building                     Canley
# 57791                          Idc Building                    D Floro
# 57792                          Idc Building                    D Floro
# 57793                          Idc Building                    D Floro
# 57794              Grepalife Annex Building        221   Sen Gil Puyat
# 57795          RCBC PLAZA YUCHENGCO TOWER 2       6819           Ayala
# 57796          RCBC PLAZA YUCHENGCO TOWER 2       6819           Ayala
# 57797          RCBC PLAZA YUCHENGCO TOWER 2       6819           Ayala
# 57798          RCBC PLAZA YUCHENGCO TOWER 2       6819           Ayala
# 57799          RCBC PLAZA YUCHENGCO TOWER 2       6819           Ayala
#
#       SAM_STSUBT               sam_estate              City  \
# 0            Ave                           Mandaluyong City
# 1            Ave                             Paranaque City
# 2            Ave                             Paranaque City
# 3            Drv  CENTRAL BUSINESS PARK 1        Pasay City
# 4             St                           Mandaluyong City
# 5            Ave                                Makati City
# 6            Ave          Bel-Air Village       Makati City
# 7            Ave          Bel-Air Village       Makati City
# 8            Ave          Bel-Air Village       Makati City
# 9            Ave          Bel-Air Village       Makati City
# 10           Ave          Bel-Air Village       Makati City
# 11           Ave          Bel-Air Village       Makati City
# 12           Ave          Bel-Air Village       Makati City
# 13           Ave          Bel-Air Village       Makati City
# 14           Ave          Bel-Air Village       Makati City
# 15           Ave          Bel-Air Village       Makati City
# 16           Ave          Bel-Air Village       Makati City
# 17           Ave          Bel-Air Village       Makati City
# 18           Ave          Bel-Air Village       Makati City
# 19           Ave          Bel-Air Village       Makati City
# 20           Ave          Bel-Air Village       Makati City
# 21           Ave           Tutuban Center       Manila City
# 22           Ave                                Quezon City
# 23            St       San Miguel Village       Manila City
# 24            St       San Miguel Village       Manila City
# 25            St       San Miguel Village       Manila City
# 26            St       San Miguel Village       Manila City
# 27           Ave                                Quezon City
# 28           Ave                                Quezon City
# 29           Ave                                Quezon City
# ...          ...                      ...               ...
# 57770         Rd           Ortigas Center        Pasig City
# 57771         Rd           Ortigas Center        Pasig City
# 57772        Ave                              Caloocan City
# 57773         Rd                                 Pasay City
# 57774        Ave                                Makati City
# 57775        Ave                                Makati City
# 57776        Ave                                Makati City
# 57777        Ave                                Makati City
# 57778        Ave                                Makati City
# 57779        Ave                                Makati City
# 57780         St                                Makati City
# 57781         St                                Makati City
# 57782         St                                Makati City
# 57783         St                                Makati City
# 57784        Ave          Legaspi Village       Makati City
# 57785         Rd                                 Pasig City
# 57786         St        BEL-AIR 2 VILLAGE       Makati City
# 57787         St                                 Pasig City
# 57788         St                                 Pasig City
# 57789         St                                 Pasig City
# 57790         Rd                                 Pasig City
# 57791         St                                 Pasig City
# 57792         St                                 Pasig City
# 57793         St                                 Pasig City
# 57794        Ave                                Makati City
# 57795        Ave          Salcedo Village       Makati City
# 57796        Ave          Salcedo Village       Makati City
# 57797        Ave          Salcedo Village       Makati City
# 57798        Ave          Salcedo Village       Makati City
# 57799        Ave          Salcedo Village       Makati City
#
#                                                 Province class_code  \
# 0      <bound method StringMethods.<lambda> of <panda...
# 1      <bound method StringMethods.<lambda> of <panda...
# 2      <bound method StringMethods.<lambda> of <panda...
# 3      <bound method StringMethods.<lambda> of <panda...
# 4      <bound method StringMethods.<lambda> of <panda...
# 5      <bound method StringMethods.<lambda> of <panda...
# 6      <bound method StringMethods.<lambda> of <panda...
# 7      <bound method StringMethods.<lambda> of <panda...
# 8      <bound method StringMethods.<lambda> of <panda...
# 9      <bound method StringMethods.<lambda> of <panda...
# 10     <bound method StringMethods.<lambda> of <panda...
# 11     <bound method StringMethods.<lambda> of <panda...
# 12     <bound method StringMethods.<lambda> of <panda...
# 13     <bound method StringMethods.<lambda> of <panda...
# 14     <bound method StringMethods.<lambda> of <panda...
# 15     <bound method StringMethods.<lambda> of <panda...
# 16     <bound method StringMethods.<lambda> of <panda...
# 17     <bound method StringMethods.<lambda> of <panda...
# 18     <bound method StringMethods.<lambda> of <panda...
# 19     <bound method StringMethods.<lambda> of <panda...
# 20     <bound method StringMethods.<lambda> of <panda...
# 21     <bound method StringMethods.<lambda> of <panda...
# 22     <bound method StringMethods.<lambda> of <panda...
# 23     <bound method StringMethods.<lambda> of <panda...
# 24     <bound method StringMethods.<lambda> of <panda...
# 25     <bound method StringMethods.<lambda> of <panda...
# 26     <bound method StringMethods.<lambda> of <panda...
# 27     <bound method StringMethods.<lambda> of <panda...
# 28     <bound method StringMethods.<lambda> of <panda...
# 29     <bound method StringMethods.<lambda> of <panda...
# ...                                                  ...        ...
# 57770  <bound method StringMethods.<lambda> of <panda...
# 57771  <bound method StringMethods.<lambda> of <panda...
# 57772  <bound method StringMethods.<lambda> of <panda...
# 57773  <bound method StringMethods.<lambda> of <panda...
# 57774  <bound method StringMethods.<lambda> of <panda...
# 57775  <bound method StringMethods.<lambda> of <panda...
# 57776  <bound method StringMethods.<lambda> of <panda...
# 57777  <bound method StringMethods.<lambda> of <panda...
# 57778  <bound method StringMethods.<lambda> of <panda...
# 57779  <bound method StringMethods.<lambda> of <panda...
# 57780  <bound method StringMethods.<lambda> of <panda...
# 57781  <bound method StringMethods.<lambda> of <panda...
# 57782  <bound method StringMethods.<lambda> of <panda...
# 57783  <bound method StringMethods.<lambda> of <panda...
# 57784  <bound method StringMethods.<lambda> of <panda...
# 57785  <bound method StringMethods.<lambda> of <panda...
# 57786  <bound method StringMethods.<lambda> of <panda...
# 57787  <bound method StringMethods.<lambda> of <panda...
# 57788  <bound method StringMethods.<lambda> of <panda...
# 57789  <bound method StringMethods.<lambda> of <panda...
# 57790  <bound method StringMethods.<lambda> of <panda...
# 57791  <bound method StringMethods.<lambda> of <panda...
# 57792  <bound method StringMethods.<lambda> of <panda...
# 57793  <bound method StringMethods.<lambda> of <panda...
# 57794  <bound method StringMethods.<lambda> of <panda...
# 57795  <bound method StringMethods.<lambda> of <panda...
# 57796  <bound method StringMethods.<lambda> of <panda...
# 57797  <bound method StringMethods.<lambda> of <panda...
# 57798  <bound method StringMethods.<lambda> of <panda...
# 57799  <bound method StringMethods.<lambda> of <panda...
#
#       class_desc acc_type
# 0                      BR
# 1                      BR
# 2                      BR
# 3                      BR
# 4                      BR
# 5                      GO
# 6                      GO
# 7                      GO
# 8                      GO
# 9                      GO
# 10                     GO
# 11                     GO
# 12                     GO
# 13                     GO
# 14                     GO
# 15                     GO
# 16                     GO
# 17                     GO
# 18                     GO
# 19                     GO
# 20                     GO
# 21                     BR
# 22                     GO
# 23                     GO
# 24                     GO
# 25                     GO
# 26                     GO
# 27                     GO
# 28                     GO
# 29                     GO
# ...          ...      ...
# 57770                  BR
# 57771                  BR
# 57772                  BR
# 57773                  BR
# 57774                  BR
# 57775                  BR
# 57776                  BR
# 57777                  BR
# 57778                  BR
# 57779                  BR
# 57780                  BR
# 57781                  BR
# 57782                  BR
# 57783                  BR
# 57784                  BR
# 57785                  BR
# 57786                  BR
# 57787                  BR
# 57788                  BR
# 57789                  BR
# 57790                  BR
# 57791                  BR
# 57792                  BR
# 57793                  BR
# 57794                  BR
# 57795                  BR
# 57796                  BR
# 57797                  BR
# 57798                  BR
# 57799                  BR
#
# [57800 rows x 14 columns]

# %%
product=pd.read_excel('Product_Lookup.xlsx')
sum(product.AREACODE==2)
# Out:
# 15

# %%
import numpy as np
classes=pd.read_excel('Company_Class.xlsx')
classes.rename(columns={'name1': 'last_name', 'name2': 'first_name'}, inplace=True)
classes_up=classes.copy()
classes_up.last_name=classes_up.last_name.str.upper()
classes_up.first_name=classes_up.first_name.str.upper()
classes_up.fillna(value='', inplace=True)
classes_up.Phone=classes_up.Phone.astype('int64')
#classes_up.class_code=classes_up.class_code.astype('int64')
classes_up = classes_up.drop(['Areacode','Product'], 1)
database_up=update.copy()
database_up.last_name=database_up.last_name.str.upper()
database_up.first_name=database_up.first_name.str.upper()
#database_up.update(classes_up)
database_up['Phone']=database_up.mem_wstd.str.slice(-7).astype('int64')
database_coded=pd.merge(database_up,classes_up, on=['Phone','last_name','first_name'], how='left')
database_coded.last_name=database.last_name
database_coded = database_coded.drop(['Phone'], 1)
#database_coded.fillna(value='', inplace=True)
#database_coded.class_code=database_coded.class_code.astype('str')
#database_coded.fillna(value='', inplace=True)
database_coded.class_code=database_coded.class_code.astype('object')
database_coded.dtypes
#database_coded.to_hdf('ha.hdf5', 'database', mode='w', format='fixed')
#database_coded
# Out:
# dir_code             object
# so_type              object
# sonumber             object
# mem_wstd             object
# first_name           object
# last_name            object
# sam_city             object
# sam_stname           object
# sam_stsubt           object
# sam_stnmfr           object
# sam_subd             object
# sam_estate           object
# sam_bldname          object
# sam_aptcod           object
# sam_aprmnt           object
# list_code            object
# acc_type             object
# old_wstd             object
# so_date              object
# joint_user           object
# regulatory_id        object
# account_no           object
# distribution_code    object
# class_code           object
# dtype: object

# %%
database_coded#[~database_coded.class_code.isnull()]
# Out:
#       dir_code so_type sonumber  mem_wstd first_name  \
# 0           MM                   25211054
# 1           MM                   28322039
# 2           MM                   22302092
# 3           MM                   22302222
# 4           MM                   22302344
# 5           MM                   22302624
# 6           MM                   22303000
# 7           MM                   22303275
# 8           MM                   22303333
# 9           MM                   22304017
# 10          MM                   22304033
# 11          MM                   22304035
# 12          MM                   22304041
# 13          MM                   22304074
# 14          MM                   22304276
# 15          MM                   22304366
# 16          MM                   22304426
# 17          MM                   22304427
# 18          MM                   22304527
# 19          MM                   22304548
# 20          MM                   22304741
# 21          MM                   22304750
# 22          MM                   22304751
# 23          MM                   22304827
# 24          MM                   22304864
# 25          MM                   22309209
# 26          MM                   22309258
# 27          MM                   22309395
# 28          MM                   22309511
# 29          MM                   22309571
# ...        ...     ...      ...       ...        ...
# 57770       MM                   29978182
# 57771       MM                   29978456
# 57772       MM                   29979000
# 57773       MM                   29979061
# 57774       MM                   29979235
# 57775       MM                   29979300
# 57776       MM                   29979362
# 57777       MM                   29979517
# 57778       MM                   29979596
# 57779       MM                   29979797
# 57780       MM                   29979916
# 57781       MM                   29980494
# 57782       MM                   29980867
# 57783       MM                   29981142
# 57784       MM                   29981145
# 57785       MM                   29981899
# 57786       MM                   29982054
# 57787       MM                   29982176
# 57788       MM                   29982282
# 57789       MM                   29982569
# 57790       MM                   29982836
# 57791       MM                   29985580
# 57792       MM                   29985677
# 57793       MM                   29985684
# 57794       MM                   29985691
# 57795       MM                   29988170
# 57796       MM                   29988171
# 57797       MM                   29988172
# 57798       MM                   29988285
# 57799       MM                   29988898
#
#                                                last_name sam_city  \
# 0                               SAN MIGUEL BREWERY, INC.     MANI
# 1                           Home Development Mutual Fund     MAKT
# 2                     Philippine Span Asia Carrier Corp.     MANI
# 3             MARIA OROSA SEAFOOD RESTAURANT CORPORATION     MANI
# 4                               PHILIPPINE BUSINESS BANK     MANI
# 5                              Security Bank Corporation     MANI
# 6                                   HENANN RESORTS, INC.     MANI
# 7                                     SPOWER CORPORATION     QUEO
# 8             MARIA OROSA SEAFOOD RESTAURANT CORPORATION     MANI
# 9                           Petron Marketing Corporation     MANI
# 10                              PHILIPPINE BUSINESS BANK     MANI
# 11                                 ASIA UNITED BANK CORP     MANI
# 12                                 ASIA UNITED BANK CORP     MANI
# 13                          Petron Marketing Corporation     MANI
# 14                         East West Banking Corporation     MANI
# 15                         East West Banking Corporation     MANI
# 16                                 ASIA UNITED BANK CORP     MANI
# 17                                 ASIA UNITED BANK CORP     MANI
# 18                       AP Cargo Logistic Network Corp.     MANI
# 19                       AP Cargo Logistic Network Corp.     MANI
# 20                              JFC TRANS & LEASING INC.     MANI
# 21                         East West Banking Corporation     QUEO
# 22                         East West Banking Corporation     QUEO
# 23                    Philippine Span Asia Carrier Corp.     MANI
# 24                  Security Bank Corporation  BENAVIDEZ     MANI
# 25                        BANK OF THE PHILIPPINE ISLANDS     MANI
# 26                          Savory Fastfood Incorporated     QUEO
# 27                          EMBASSY OF THE UNITED STATES     MANI
# 28     CITY ROYAL GENERAL INSURANCE AGENCY MANAGEMENT...     PASY
# 29                                  GREATFIT MAKERS INC.     MANI
# ...                                                  ...      ...
# 57770                        City Government of San Juan      SAN
# 57771                                               RCBC     MARK
# 57772                                OPTIMUM SOURCE, INC     PASI
# 57773             GAMPIK CONSTRUCTION & DEVELOPMENT INC.     MARK
# 57774                                           WILDFIRE     MAND
# 57775                      PHILIPPINE TRUST BANK COMPANY     MARK
# 57776                   FAMILY FUN PORTRAIT STUDIOS INC.     MAND
# 57777                                       PR GAZ, INC.     MARK
# 57778                    SYCIP GORRES VELAYO AND COMPANY     PASI
# 57779                             OFFICE WAREHOUSE, INC.     QUEO
# 57780  THE LAW FIRM OF BARTOLOME, SALAZAR, PALOMAR AN...     PASI
# 57781                                HONDA CARS MARIKINA     MARK
# 57782                                HONDA CARS MARIKINA     MARK
# 57783                                HONDA CARS MARIKINA     MARK
# 57784                                HONDA CARS MARIKINA     MARK
# 57785                               JANRICKXAN MARKETING     MARK
# 57786                        Fresh N` Famous Foods, Inc.     MARK
# 57787                         SERVER SCOUT INTERNET CAFE     MARK
# 57788                    FOOTWORKS MARKETING CORPORATION     MARK
# 57789                    FOOTWORKS MARKETING CORPORATION     MARK
# 57790                            PHILIPPINE SAVINGS BANK     MARK
# 57791                              RWP INTERNATIONAL INC     MARK
# 57792                        CONQUEROR INTERNATIONAL INC     MARK
# 57793                        CONQUEROR INTERNATIONAL INC     MARK
# 57794                              RWP INTERNATIONAL INC     MARK
# 57795                METROPOLITAN BANK AND TRUST COMPANY     MARK
# 57796                METROPOLITAN BANK AND TRUST COMPANY     MARK
# 57797                METROPOLITAN BANK AND TRUST COMPANY     MARK
# 57798                                  P J LHUILLIER INC     MARK
# 57799                        MARIST COLLEGE INCORPORATED     MARK
#
#               sam_stname sam_stsubt sam_stnmfr    ...            sam_aprmnt  \
# 0                H LOPEZ        BVD               ...
# 1          SEN GIL PUYAT        AVE        358    ...
# 2              RAXA BAGO         ST       2071    ...
# 3             MA Y OROSA         ST       1015    ...
# 4          J ABAD SANTOS        AVE       1737    ...
# 5                TAYUMAN         ST        287    ...
# 6               A MABINI         ST       1212    ...
# 7            STO DOMINGO         ST         49    ...
# 8             MA Y OROSA         ST       1015    ...
# 9                  FIRST         ST               ...      PETRON MRKT CORP
# 10         J ABAD SANTOS        AVE       1737    ...
# 11             C M RECTO        AVE               ...
# 12             C M RECTO        AVE               ...
# 13             PEDRO GIL         ST               ...
# 14                 RIZAL        AVE       2423    ...
# 15                 RIZAL        AVE       2412    ...
# 16             JUAN LUNA         ST       2498    ...
# 17             JUAN LUNA         ST       2498    ...
# 18             C M RECTO        AVE       1141    ...
# 19             C M RECTO        AVE       1141    ...
# 20                 NAKAR         ST       2450    ...
# 21                 MAYON         ST        181    ...
# 22                 MAYON         ST        181    ...
# 23             RAXA BAGO         ST       2071    ...
# 24             BENAVIDEZ         ST       1264    ...
# 25           P OCAMPO SR         ST        780    ...
# 26                QUEZON        AVE        121    ...
# 27           M ADRIATICO         ST       1745    ...                    3B
# 28                  TAFT        AVE       1744    ...
# 29             C M RECTO        AVE               ...                 2F-10
# ...                  ...        ...        ...    ...                   ...
# 57770       PINAGLABANAN         ST               ...
# 57771        A BONIFACIO        AVE         84    ...
# 57772       F ORTIGAS JR         RD               ...                  2606
# 57773          GEN MENEZ         ST         38    ...
# 57774            PIONEER         ST        126    ...
# 57775           SUMULONG        HWY         17    ...
# 57776               SHAW        BVD               ...                  4001
# 57777          J P RIZAL         ST        480    ...
# 57778               RUBY         RD               ...                 A & C
# 57779     E RODRIGUEZ JR        AVE        169    ...
# 57780       F ORTIGAS JR         RD               ...                  2003
# 57781        A BONIFACIO        AVE               ...
# 57782        A BONIFACIO        AVE               ...
# 57783        A BONIFACIO        AVE               ...
# 57784        A BONIFACIO        AVE               ...
# 57785           PANORAMA         ST               ...            049-BL-013
# 57786  LIWASANG KALAYAAN         ST               ...              CHOWKING
# 57787          J P RIZAL         ST        713    ...
# 57788        E RODRIGUEZ         ST         84    ...
# 57789        E RODRIGUEZ         ST         84    ...
# 57790      BAYAN-BAYANAN        AVE         22    ...
# 57791          E MENDOZA         ST               ...           014-BL-002B
# 57792        E RODRIGUEZ         ST         88    ...
# 57793          E MENDOZA         ST          8    ...
# 57794          E MENDOZA         ST               ...           014-BL-002B
# 57795           SUMULONG        HWY               ...
# 57796           SUMULONG        HWY               ...
# 57797           SUMULONG        HWY               ...
# 57798         B G MOLINA         ST               ...            016-BL-002
# 57799             MARIST         ST               ...
#
#       list_code acc_type old_wstd so_date joint_user regulatory_id account_no  \
# 0            PB       BR                                       PLD  150944589
# 1            PB       GO                                       PLD  652625185
# 2            PB       BR                                       PLD  651517141
# 3            PB       BR                                       PLD  652545998
# 4            PB       BR                                       PLD  651408040
# 5            PB       BR                                       PLD  651011256
# 6            PB       BR                                       PLD  652517501
# 7            PB       BR                                       PLD  652204864
# 8            PB       BR                                       PLD  652545998
# 9            PB       BR                                       PLD  652205690
# 10           PB       BR                                       PLD  651408059
# 11           PB       BR                                       PLD  167550126
# 12           PB       BR                                       PLD  167550142
# 13           PB       BR                                       PLD  652205712
# 14           PB       BR                                       PLD  651338255
# 15           PB       BR                                       PLD  651452376
# 16           PB       BR                                       PLD  651519071
# 17           PB       BR                                       PLD  651519098
# 18           PB       BR                                       PLD  651572126
# 19           PB       BR                                       PLD  651572126
# 20           PB       BR                                       PLD  652190391
# 21           PB       BR                                       PLD  652212948
# 22           PB       BR                                       PLD  652212387
# 23           PB       BR                                       PLD   30775651
# 24           PB       BR                                       PLD  651393515
# 25           PB       BR                                       PLD  652888097
# 26           PB       BR                                       PLD  652853757
# 27           PB       BR                                       PLD  652828809
# 28           PB       BR                                       PLD  652866956
# 29           PB       BR                                       PLD  652759335
# ...         ...      ...      ...     ...        ...           ...        ...
# 57770        PB       GO                                       PLD  651022142
# 57771        PB       BR                                       PLD   98100784
# 57772        PB       BR                                       PLD  652788483
# 57773        PB       BR                                       PLD  182267570
# 57774        PB       BR                                       PLD  652394388
# 57775        PB       BR                                       PLD  652387276
# 57776        PB       BR                                       PLD  652409423
# 57777        PB       BR                                       PLD  652415113
# 57778        PB       BR                                       PLD  652700896
# 57779        PB       BR                                       PLD  651323789
# 57780        PB       BR                                       PLD  652635288
# 57781        PB       BR                                       PLD  121418533
# 57782        PB       BR                                       PLD  121418762
# 57783        PB       BR                                       PLD  121418800
# 57784        PB       BR                                       PLD  121418835
# 57785        PB       BR                                       PLD  186292847
# 57786        PB       BR                                       PLD  128049606
# 57787        PB       BR                                       PLD  190985725
# 57788        PB       BR                                       PLD  199029754
# 57789        PB       BR                                       PLD  199030418
# 57790        PB       BR                                       PLD  117866564
# 57791        PB       BR                                       PLD  175460608
# 57792        PB       BR                                       PLD  175460330
# 57793        PB       BR                                       PLD  175460470
# 57794        PB       BR                                       PLD  175460160
# 57795        PB       BR                                       PLD  153223203
# 57796        PB       BR                                       PLD  153223173
# 57797        PB       BR                                       PLD  153223122
# 57798        PB       BR                                       PLD  154594000
# 57799        PB       BR                                       PLD  152076924
#
#                                     distribution_code class_code
# 0           METRO MANILA                  MANILA CITY        NaN
# 1           METRO MANILA                  MAKATI CITY        NaN
# 2           METRO MANILA                  MANILA CITY        NaN
# 3           METRO MANILA                  MANILA CITY        NaN
# 4           METRO MANILA                  MANILA CITY        NaN
# 5           METRO MANILA                  MANILA CITY        NaN
# 6           METRO MANILA                  MANILA CITY        NaN
# 7           METRO MANILA                  QUEZON CITY        NaN
# 8           METRO MANILA                  MANILA CITY        NaN
# 9           METRO MANILA                  MANILA CITY        NaN
# 10          METRO MANILA                  MANILA CITY        NaN
# 11          METRO MANILA                  MANILA CITY        NaN
# 12          METRO MANILA                  MANILA CITY        NaN
# 13          METRO MANILA                  MANILA CITY        NaN
# 14          METRO MANILA                  MANILA CITY        NaN
# 15          METRO MANILA                  MANILA CITY        NaN
# 16          METRO MANILA                  MANILA CITY        NaN
# 17          METRO MANILA                  MANILA CITY        NaN
# 18          METRO MANILA                  MANILA CITY        NaN
# 19          METRO MANILA                  MANILA CITY        NaN
# 20          METRO MANILA                  MANILA CITY        NaN
# 21          METRO MANILA                  QUEZON CITY        NaN
# 22          METRO MANILA                  QUEZON CITY        NaN
# 23          METRO MANILA                  MANILA CITY        NaN
# 24          METRO MANILA                  MANILA CITY        NaN
# 25          METRO MANILA                  MANILA CITY        NaN
# 26          METRO MANILA                  QUEZON CITY        NaN
# 27          METRO MANILA                  MANILA CITY        NaN
# 28           METRO MANILA                  PASAY CITY        NaN
# 29          METRO MANILA                  MANILA CITY        NaN
# ...                                               ...        ...
# 57770     METRO MANILA                  SAN JUAN CITY        NaN
# 57771     METRO MANILA                  MARIKINA CITY        NaN
# 57772        METRO MANILA                  PASIG CITY        NaN
# 57773     METRO MANILA                  MARIKINA CITY        NaN
# 57774  METRO MANILA                  MANDALUYONG CITY        NaN
# 57775     METRO MANILA                  MARIKINA CITY        NaN
# 57776  METRO MANILA                  MANDALUYONG CITY        NaN
# 57777     METRO MANILA                  MARIKINA CITY        NaN
# 57778        METRO MANILA                  PASIG CITY        NaN
# 57779       METRO MANILA                  QUEZON CITY        NaN
# 57780        METRO MANILA                  PASIG CITY        NaN
# 57781     METRO MANILA                  MARIKINA CITY        NaN
# 57782     METRO MANILA                  MARIKINA CITY        NaN
# 57783     METRO MANILA                  MARIKINA CITY        NaN
# 57784     METRO MANILA                  MARIKINA CITY        NaN
# 57785     METRO MANILA                  MARIKINA CITY        NaN
# 57786     METRO MANILA                  MARIKINA CITY        NaN
# 57787     METRO MANILA                  MARIKINA CITY        NaN
# 57788     METRO MANILA                  MARIKINA CITY        NaN
# 57789     METRO MANILA                  MARIKINA CITY        NaN
# 57790     METRO MANILA                  MARIKINA CITY        NaN
# 57791     METRO MANILA                  MARIKINA CITY        NaN
# 57792     METRO MANILA                  MARIKINA CITY        NaN
# 57793     METRO MANILA                  MARIKINA CITY        NaN
# 57794     METRO MANILA                  MARIKINA CITY        NaN
# 57795     METRO MANILA                  MARIKINA CITY        NaN
# 57796     METRO MANILA                  MARIKINA CITY        NaN
# 57797     METRO MANILA                  MARIKINA CITY        NaN
# 57798     METRO MANILA                  MARIKINA CITY        NaN
# 57799     METRO MANILA                  MARIKINA CITY        NaN
#
# [57800 rows x 24 columns]

# %%
x=pd.read_hdf('ha.hdf5')

# %%
x[~x.class_code.isnull()]
# Out:
#       dir_code so_type sonumber  mem_wstd first_name  \
# 3227        MM                   22885101
# 6300        MM                   23710329
# 13987       MM                   25310891
# 18002       MM                   25842303
# 23944       MM                   26712239
# 32488       MM                   28102991
# 34986       MM                   28161186
# 36849       MM                   28222529
# 41954       MM                   28448441
# 53467       MM                   29217686
#
#                                               last_name sam_city  \
# 3227                  ASIATIC ALUMINUM PRODUCTS COMPANY     MALA
# 6300   ROOSEVELT ALUMINUM PRODUCTS COMPANY INCORPORATED     QUEO
# 13987        NEW TOPBEST LUMBER CONSTRUCTION SUPPLY INC     MAND
# 18002                                       ePLDT, Inc.     PASI
# 23944                      ITX DISTRIBUTORS CORPORATION     PASI
# 32488                       SHIMEX TRADING INCORPORATED     MAKT
# 34986                                   AGCHEM MFG CORP     MAKT
# 36849                      AAI WORLDWIDE LOGISTICS INC.     PARQ
# 41954                                   CHAN C BROS INC     PASY
# 53467                  CHARTERED ADJUSTERS INCORPORATED     QUEO
#
#             sam_stname sam_stsubt sam_stnmfr     ...     sam_aprmnt list_code  \
# 3227             CELIA         ST         55     ...                       PB
# 6300   JUDGE JUAN LUNA         ST        183     ...                       PB
# 13987             EDSA        AVE        282     ...                       PB
# 18002           CANLEY         RD                ...                       PB
# 23944        ROSEMARIE        LNE          5     ...                       PB
# 32488      CHINO ROCES        AVE       2263     ...            305        PB
# 34986       A S ARNAIZ        AVE        835     ...                       PB
# 36849          KAINGIN         RD                ...                       PB
# 41954        TOLENTINO         ST       2225     ...                       PB
# 53467             EDSA        AVE        784     ...              5        PB
#
#       acc_type old_wstd so_date                      joint_user regulatory_id  \
# 3227        BR                                                            PLD
# 6300        BR                                                            PLD
# 13987       BR                                                            PLD
# 18002       BR                                                            PLD
# 23944       BR                                                            PLD
# 32488       BR                                                            PLD
# 34986       BR                                                            PLD
# 36849       BR                                                            PLD
# 41954       BR                   LIWAYWAY MARKETING CORPORATION           PLD
# 53467       BR                                                            PLD
#
#       account_no                               distribution_code  class_code
# 3227     3728439      METRO MANILA                  MALABON CITY      104491
# 6300    35916962       METRO MANILA                  QUEZON CITY      104491
# 13987    6338607  METRO MANILA                  MANDALUYONG CITY      104491
# 18002  651952212        METRO MANILA                  PASIG CITY  6.9697e+06
# 23944    7271654        METRO MANILA                  PASIG CITY      104437
# 32488    6823262       METRO MANILA                  MAKATI CITY      104377
# 34986    6702074       METRO MANILA                  MAKATI CITY      104433
# 36849   80398727    METRO MANILA                  PARANAQUE CITY      100000
# 41954   30813820        METRO MANILA                  PASAY CITY      104392
# 53467   28800541       METRO MANILA                  QUEZON CITY      104393
#
# [10 rows x 24 columns]

# %%
line=x.ix[1]
line.sam_city=''
line
# Out:
# dir_code                                                    MM
# so_type
# sonumber
# mem_wstd                                              28322039
# first_name
# last_name                         Home Development Mutual Fund
# sam_city
# sam_stname                                       SEN GIL PUYAT
# sam_stsubt                                                 AVE
# sam_stnmfr                                                 358
# sam_subd
# sam_estate                                     SALCEDO VILLAGE
# sam_bldname                                  PETRON MEGA PLAZA
# sam_aptcod
# sam_aprmnt
# list_code                                                   PB
# acc_type                                                    GO
# old_wstd
# so_date
# joint_user
# regulatory_id                                              PLD
# account_no                                           652625185
# distribution_code    METRO MANILA                  MAKATI CITY
# class_code                                                 NaN
# Name: 1, dtype: object

# %%
rr_crm
# Out:
#        Areacode    Phone                                              name1  \
# 0             2  5211054                           San Miguel Brewery, Inc.
# 1             2  8322039                       Home Development Mutual Fund
# 2             2  2302092                 Philippine Span Asia Carrier Corp.
# 3             2  2302222         Maria Orosa Seafood Restaurant Corporation
# 4             2  2302344                           Philippine Business Bank
# 5             2  2302624                          Security Bank Corporation
# 6             2  2303000                               Henann Resorts, Inc.
# 7             2  2303275                                 Spower Corporation
# 8             2  2303333         Maria Orosa Seafood Restaurant Corporation
# 9             2  2304017                       Petron Marketing Corporation
# 10            2  2304033                           Philippine Business Bank
# 11            2  2304035                              Asia United Bank Corp
# 12            2  2304041                              Asia United Bank Corp
# 13            2  2304074                       Petron Marketing Corporation
# 14            2  2304276                      East West Banking Corporation
# 15            2  2304366                      East West Banking Corporation
# 16            2  2304426                              Asia United Bank Corp
# 17            2  2304427                              Asia United Bank Corp
# 18            2  2304527                    AP Cargo Logistic Network Corp.
# 19            2  2304548                    AP Cargo Logistic Network Corp.
# 20            2  2304741                           Jfc Trans & Leasing Inc.
# 21            2  2304750                      East West Banking Corporation
# 22            2  2304751                      East West Banking Corporation
# 23            2  2304827                 Philippine Span Asia Carrier Corp.
# 24            2  2304864               Security Bank Corporation  BENAVIDEZ
# 25            2  2309209                     Bank of the Philippine Islands
# 26            2  2309258                       Savory Fastfood Incorporated
# 27            2  2309395                       Embassy of the United States
# 28            2  2309511  City Royal General Insurance Agency Management...
# 29            2  2309571                               Greatfit Makers Inc.
# ...         ...      ...                                                ...
# 57770         2  9978182                        City Government of San Juan
# 57771         2  9978456                                               Rcbc
# 57772         2  9979000                                Optimum Source, Inc
# 57773         2  9979061             Gampik Construction & Development Inc.
# 57774         2  9979235                                           Wildfire
# 57775         2  9979300                      Philippine Trust Bank Company
# 57776         2  9979362                   Family Fun Portrait Studios Inc.
# 57777         2  9979517                                       Pr Gaz, Inc.
# 57778         2  9979596                    Sycip Gorres Velayo and Company
# 57779         2  9979797                             Office Warehouse, Inc.
# 57780         2  9979916  The Law Firm of Bartolome, Salazar, Palomar an...
# 57781         2  9980494                                Honda Cars Marikina
# 57782         2  9980867                                Honda Cars Marikina
# 57783         2  9981142                                Honda Cars Marikina
# 57784         2  9981145                                Honda Cars Marikina
# 57785         2  9981899                               Janrickxan Marketing
# 57786         2  9982054                        Fresh N` Famous Foods, Inc.
# 57787         2  9982176                         Server Scout Internet Cafe
# 57788         2  9982282                    Footworks Marketing Corporation
# 57789         2  9982569                    Footworks Marketing Corporation
# 57790         2  9982836                            Philippine Savings Bank
# 57791         2  9985580                              Rwp International Inc
# 57792         2  9985677                        Conqueror International Inc
# 57793         2  9985684                        Conqueror International Inc
# 57794         2  9985691                              Rwp International Inc
# 57795         2  9988170                Metropolitan Bank and Trust Company
# 57796         2  9988171                Metropolitan Bank and Trust Company
# 57797         2  9988172                Metropolitan Bank and Trust Company
# 57798         2  9988285                                  P J Lhuillier Inc
# 57799         2  9988898                        Marist College Incorporated
#
#       name2                 SAM_BLDNAME SAM_STNMFR         SAM_STNAME  \
# 0                                                             H Lopez
# 1                     Petron Mega Plaza        358      Sen Gil Puyat
# 2                                             2071          Raxa Bago
# 3                                             1015         Ma Y Orosa
# 4                                             1737      J Abad Santos
# 5                                              287            Tayuman
# 6              Boracay Regency Building       1212           A Mabini
# 7                                               49        Sto Domingo
# 8                                             1015         Ma Y Orosa
# 9                                                               First
# 10                                            1737      J Abad Santos
# 11                TUTUBAN CENTER MALL 1                     C M Recto
# 12                TUTUBAN CENTER MALL 1                     C M Recto
# 13                                                          Pedro Gil
# 14                                            2423              Rizal
# 15                                            2412              Rizal
# 16                                            2498          Juan Luna
# 17                                            2498          Juan Luna
# 18                         Gocheco Bldg       1141          C M Recto
# 19                         Gocheco Bldg       1141          C M Recto
# 20                                            2450              Nakar
# 21                                             181              Mayon
# 22                                             181              Mayon
# 23                                            2071          Raxa Bago
# 24                                            1264          Benavidez
# 25             Bpi Family Bank Building        780        P Ocampo Sr
# 26                                             121             Quezon
# 27                    Rosario Apartment       1745        M Adriatico
# 28                                            1744               Taft
# 29                  999 SHOPPING MALL 2                     C M Recto
# ...     ...                         ...        ...                ...
# 57770            New San Juan City Hall                  Pinaglabanan
# 57771                     Riverbank Ctr         84        A Bonifacio
# 57772            Orient Square Building                  F Ortigas Jr
# 57773                                           38          Gen Menez
# 57774                    FMF BUILDING 2        126            Pioneer
# 57775                                           17           Sumulong
# 57776        Edsa Shangri-La Plaza Mall                          Shaw
# 57777                                          480          J P Rizal
# 57778         Robinsons Cyberscape Beta                          Ruby
# 57779          Eastgate Center Building        169     E Rodriguez Jr
# 57780             Taipan Place Building                  F Ortigas Jr
# 57781                                                     A Bonifacio
# 57782                                                     A Bonifacio
# 57783                                                     A Bonifacio
# 57784                                                     A Bonifacio
# 57785                                                        Panorama
# 57786                        C & P Mall             Liwasang Kalayaan
# 57787                                          713          J P Rizal
# 57788                                           84        E Rodriguez
# 57789                                           84        E Rodriguez
# 57790                                           22      Bayan-Bayanan
# 57791                                                       E Mendoza
# 57792                                           88        E Rodriguez
# 57793                                            8          E Mendoza
# 57794                                                       E Mendoza
# 57795                                                        Sumulong
# 57796                                                        Sumulong
# 57797                                                        Sumulong
# 57798                                                      B G Molina
# 57799                                                          Marist
#
#       SAM_STSUBT                   sam_estate              City  \
# 0            Bvd                        Balut       Manila City
# 1            Ave              Salcedo Village       Makati City
# 2             St                                    Manila City
# 3             St                                    Manila City
# 4            Ave                                    Manila City
# 5             St                                    Manila City
# 6             St                                    Manila City
# 7             St                                    Quezon City
# 8             St                                    Manila City
# 9             St                                    Manila City
# 10           Ave                                    Manila City
# 11           Ave               Tutuban Center       Manila City
# 12           Ave               Tutuban Center       Manila City
# 13            St                                    Manila City
# 14           Ave                                    Manila City
# 15           Ave                                    Manila City
# 16            St                   Gagalangin       Manila City
# 17            St                   Gagalangin       Manila City
# 18           Ave                                    Manila City
# 19           Ave                                    Manila City
# 20            St                                    Manila City
# 21            St                                    Quezon City
# 22            St                                    Quezon City
# 23            St                                    Manila City
# 24            St                                    Manila City
# 25            St                                    Manila City
# 26           Ave                                    Quezon City
# 27            St                                    Manila City
# 28           Ave                                     Pasay City
# 29           Ave                                    Manila City
# ...          ...                          ...               ...
# 57770         St                                  San Juan City
# 57771        Ave                                  Marikina City
# 57772         Rd               Ortigas Center        Pasig City
# 57773         St                                  Marikina City
# 57774         St                               Mandaluyong City
# 57775        Hwy                                  Marikina City
# 57776        Bvd                               Mandaluyong City
# 57777         St                                  Marikina City
# 57778         Rd               Ortigas Center        Pasig City
# 57779        Ave                                    Quezon City
# 57780         Rd               Ortigas Center        Pasig City
# 57781        Ave                                  Marikina City
# 57782        Ave                                  Marikina City
# 57783        Ave                                  Marikina City
# 57784        Ave                                  Marikina City
# 57785         St  RANCHO ESTATE SUBDIVISION 3     Marikina City
# 57786         St                                  Marikina City
# 57787         St                                  Marikina City
# 57788         St           Ronquillo Compound     Marikina City
# 57789         St           Ronquillo Compound     Marikina City
# 57790        Ave                                  Marikina City
# 57791         St                                  Marikina City
# 57792         St           Ronquillo Compound     Marikina City
# 57793         St                                  Marikina City
# 57794         St                                  Marikina City
# 57795        Hwy                                  Marikina City
# 57796        Hwy                                  Marikina City
# 57797        Hwy                                  Marikina City
# 57798         St                                  Marikina City
# 57799         St               Maryville Subd     Marikina City
#
#                                                 Province class_code  \
# 0      <bound method StringMethods.<lambda> of <panda...
# 1      <bound method StringMethods.<lambda> of <panda...
# 2      <bound method StringMethods.<lambda> of <panda...
# 3      <bound method StringMethods.<lambda> of <panda...
# 4      <bound method StringMethods.<lambda> of <panda...
# 5      <bound method StringMethods.<lambda> of <panda...
# 6      <bound method StringMethods.<lambda> of <panda...
# 7      <bound method StringMethods.<lambda> of <panda...
# 8      <bound method StringMethods.<lambda> of <panda...
# 9      <bound method StringMethods.<lambda> of <panda...
# 10     <bound method StringMethods.<lambda> of <panda...
# 11     <bound method StringMethods.<lambda> of <panda...
# 12     <bound method StringMethods.<lambda> of <panda...
# 13     <bound method StringMethods.<lambda> of <panda...
# 14     <bound method StringMethods.<lambda> of <panda...
# 15     <bound method StringMethods.<lambda> of <panda...
# 16     <bound method StringMethods.<lambda> of <panda...
# 17     <bound method StringMethods.<lambda> of <panda...
# 18     <bound method StringMethods.<lambda> of <panda...
# 19     <bound method StringMethods.<lambda> of <panda...
# 20     <bound method StringMethods.<lambda> of <panda...
# 21     <bound method StringMethods.<lambda> of <panda...
# 22     <bound method StringMethods.<lambda> of <panda...
# 23     <bound method StringMethods.<lambda> of <panda...
# 24     <bound method StringMethods.<lambda> of <panda...
# 25     <bound method StringMethods.<lambda> of <panda...
# 26     <bound method StringMethods.<lambda> of <panda...
# 27     <bound method StringMethods.<lambda> of <panda...
# 28     <bound method StringMethods.<lambda> of <panda...
# 29     <bound method StringMethods.<lambda> of <panda...
# ...                                                  ...        ...
# 57770  <bound method StringMethods.<lambda> of <panda...
# 57771  <bound method StringMethods.<lambda> of <panda...
# 57772  <bound method StringMethods.<lambda> of <panda...
# 57773  <bound method StringMethods.<lambda> of <panda...
# 57774  <bound method StringMethods.<lambda> of <panda...
# 57775  <bound method StringMethods.<lambda> of <panda...
# 57776  <bound method StringMethods.<lambda> of <panda...
# 57777  <bound method StringMethods.<lambda> of <panda...
# 57778  <bound method StringMethods.<lambda> of <panda...
# 57779  <bound method StringMethods.<lambda> of <panda...
# 57780  <bound method StringMethods.<lambda> of <panda...
# 57781  <bound method StringMethods.<lambda> of <panda...
# 57782  <bound method StringMethods.<lambda> of <panda...
# 57783  <bound method StringMethods.<lambda> of <panda...
# 57784  <bound method StringMethods.<lambda> of <panda...
# 57785  <bound method StringMethods.<lambda> of <panda...
# 57786  <bound method StringMethods.<lambda> of <panda...
# 57787  <bound method StringMethods.<lambda> of <panda...
# 57788  <bound method StringMethods.<lambda> of <panda...
# 57789  <bound method StringMethods.<lambda> of <panda...
# 57790  <bound method StringMethods.<lambda> of <panda...
# 57791  <bound method StringMethods.<lambda> of <panda...
# 57792  <bound method StringMethods.<lambda> of <panda...
# 57793  <bound method StringMethods.<lambda> of <panda...
# 57794  <bound method StringMethods.<lambda> of <panda...
# 57795  <bound method StringMethods.<lambda> of <panda...
# 57796  <bound method StringMethods.<lambda> of <panda...
# 57797  <bound method StringMethods.<lambda> of <panda...
# 57798  <bound method StringMethods.<lambda> of <panda...
# 57799  <bound method StringMethods.<lambda> of <panda...
#
#       class_desc acc_type
# 0                      BR
# 1                      GO
# 2                      BR
# 3                      BR
# 4                      BR
# 5                      BR
# 6                      BR
# 7                      BR
# 8                      BR
# 9                      BR
# 10                     BR
# 11                     BR
# 12                     BR
# 13                     BR
# 14                     BR
# 15                     BR
# 16                     BR
# 17                     BR
# 18                     BR
# 19                     BR
# 20                     BR
# 21                     BR
# 22                     BR
# 23                     BR
# 24                     BR
# 25                     BR
# 26                     BR
# 27                     BR
# 28                     BR
# 29                     BR
# ...          ...      ...
# 57770                  GO
# 57771                  BR
# 57772                  BR
# 57773                  BR
# 57774                  BR
# 57775                  BR
# 57776                  BR
# 57777                  BR
# 57778                  BR
# 57779                  BR
# 57780                  BR
# 57781                  BR
# 57782                  BR
# 57783                  BR
# 57784                  BR
# 57785                  BR
# 57786                  BR
# 57787                  BR
# 57788                  BR
# 57789                  BR
# 57790                  BR
# 57791                  BR
# 57792                  BR
# 57793                  BR
# 57794                  BR
# 57795                  BR
# 57796                  BR
# 57797                  BR
# 57798                  BR
# 57799                  BR
#
# [57800 rows x 14 columns]
